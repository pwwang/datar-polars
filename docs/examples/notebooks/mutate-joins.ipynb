# %%
# https://dplyr.tidyverse.org/reference/mutate-joins.html
# %run nb_helpers.py

from datar.data import band_members, band_instruments, band_instruments2
from datar.all import *

nb_header(inner_join, left_join, right_join, full_join, book='mutate-joins')
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Fmutate-joins.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ inner_join</div>
# ##### Inner join two data frames by matching rows.
#
# The original API:
# https://dplyr.tidyverse.org/reference/join.html
#
# ##### Args:
# &emsp;&emsp;`x`: A data frame
# &emsp;&emsp;`y`: A data frame
# &emsp;&emsp;`by`: A list of column names to join by.
# &emsp;&emsp;&emsp;&emsp;If None, use the intersection of the columns of x and y.
#
# &emsp;&emsp;`copy`: If True, always copy the data.
# &emsp;&emsp;`suffix`: A tuple of suffixes to apply to overlapping columns.
# &emsp;&emsp;`keep`: If True, keep the grouping variables in the output.
# &emsp;&emsp;`na_matches`: How should NA values be matched?
# &emsp;&emsp;&emsp;&emsp;"na": NA values are equal.
# &emsp;&emsp;&emsp;&emsp;"never": NA values are never matched.
#
# &emsp;&emsp;`multiple`: How should multiple matches be handled?
# &emsp;&emsp;&emsp;&emsp;"all": All matches are returned.
# &emsp;&emsp;&emsp;&emsp;"first": The first match is returned.
# &emsp;&emsp;&emsp;&emsp;"last": The last match is returned.
# &emsp;&emsp;&emsp;&emsp;"any": Any of the matched rows in y
#
# &emsp;&emsp;`unmatched`: How should unmatched keys that would result in dropped rows
# &emsp;&emsp;&emsp;&emsp;be handled?
# &emsp;&emsp;&emsp;&emsp;"drop": Drop unmatched keys.
# &emsp;&emsp;&emsp;&emsp;"error": Raise an error.
#
# &emsp;&emsp;`relationship`: The relationship between x and y.
# &emsp;&emsp;&emsp;&emsp;`None`: No expected relationship.
#
# &emsp;&emsp;&emsp;&emsp;"one_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"one_to_many": Each row in x matches zero or more rows in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_many": Each row in x matches zero or more rows in y.
#
# ##### Returns:
# &emsp;&emsp;A data frame
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ left_join</div>
# ##### Left join two data frames by matching rows.
#
# The original API:
# https://dplyr.tidyverse.org/reference/join.html
#
# ##### Args:
# &emsp;&emsp;`x`: A data frame
# &emsp;&emsp;`y`: A data frame
# &emsp;&emsp;`by`: A list of column names to join by.
# &emsp;&emsp;&emsp;&emsp;If None, use the intersection of the columns of x and y.
#
# &emsp;&emsp;`copy`: If True, always copy the data.
# &emsp;&emsp;`suffix`: A tuple of suffixes to apply to overlapping columns.
# &emsp;&emsp;`keep`: If True, keep the grouping variables in the output.
# &emsp;&emsp;`na_matches`: How should NA values be matched?
# &emsp;&emsp;&emsp;&emsp;"na": NA values are equal.
# &emsp;&emsp;&emsp;&emsp;"never": NA values are never matched.
#
# &emsp;&emsp;`multiple`: How should multiple matches be handled?
# &emsp;&emsp;&emsp;&emsp;"all": All matches are returned.
# &emsp;&emsp;&emsp;&emsp;"first": The first match is returned.
# &emsp;&emsp;&emsp;&emsp;"last": The last match is returned.
# &emsp;&emsp;&emsp;&emsp;"any": Any of the matched rows in y
#
# &emsp;&emsp;`unmatched`: How should unmatched keys that would result in dropped rows
# &emsp;&emsp;&emsp;&emsp;be handled?
# &emsp;&emsp;&emsp;&emsp;"drop": Drop unmatched keys.
# &emsp;&emsp;&emsp;&emsp;"error": Raise an error.
#
# &emsp;&emsp;`relationship`: The relationship between x and y.
# &emsp;&emsp;&emsp;&emsp;`None`: No expected relationship.
#
# &emsp;&emsp;&emsp;&emsp;"one_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"one_to_many": Each row in x matches zero or more rows in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_many": Each row in x matches zero or more rows in y.
#
# ##### Returns:
# &emsp;&emsp;A data frame
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ right_join</div>
# ##### Right join two data frames by matching rows.
#
# The original API:
# https://dplyr.tidyverse.org/reference/join.html
#
# ##### Args:
# &emsp;&emsp;`x`: A data frame
# &emsp;&emsp;`y`: A data frame
# &emsp;&emsp;`by`: A list of column names to join by.
# &emsp;&emsp;&emsp;&emsp;If None, use the intersection of the columns of x and y.
#
# &emsp;&emsp;`copy`: If True, always copy the data.
# &emsp;&emsp;`suffix`: A tuple of suffixes to apply to overlapping columns.
# &emsp;&emsp;`keep`: If True, keep the grouping variables in the output.
# &emsp;&emsp;`na_matches`: How should NA values be matched?
# &emsp;&emsp;&emsp;&emsp;"na": NA values are equal.
# &emsp;&emsp;&emsp;&emsp;"never": NA values are never matched.
#
# &emsp;&emsp;`multiple`: How should multiple matches be handled?
# &emsp;&emsp;&emsp;&emsp;"all": All matches are returned.
# &emsp;&emsp;&emsp;&emsp;"first": The first match is returned.
# &emsp;&emsp;&emsp;&emsp;"last": The last match is returned.
# &emsp;&emsp;&emsp;&emsp;"any": Any of the matched rows in y
#
# &emsp;&emsp;`unmatched`: How should unmatched keys that would result in dropped rows
# &emsp;&emsp;&emsp;&emsp;be handled?
# &emsp;&emsp;&emsp;&emsp;"drop": Drop unmatched keys.
# &emsp;&emsp;&emsp;&emsp;"error": Raise an error.
#
# &emsp;&emsp;`relationship`: The relationship between x and y.
# &emsp;&emsp;&emsp;&emsp;`None`: No expected relationship.
#
# &emsp;&emsp;&emsp;&emsp;"one_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"one_to_many": Each row in x matches zero or more rows in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_many": Each row in x matches zero or more rows in y.
#
# ##### Returns:
# &emsp;&emsp;A data frame
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ full_join</div>
# ##### Full join two data frames by matching rows.
#
# The original API:
# https://dplyr.tidyverse.org/reference/join.html
#
# ##### Args:
# &emsp;&emsp;`x`: A data frame
# &emsp;&emsp;`y`: A data frame
# &emsp;&emsp;`by`: A list of column names to join by.
# &emsp;&emsp;&emsp;&emsp;If None, use the intersection of the columns of x and y.
#
# &emsp;&emsp;`copy`: If True, always copy the data.
# &emsp;&emsp;`suffix`: A tuple of suffixes to apply to overlapping columns.
# &emsp;&emsp;`keep`: If True, keep the grouping variables in the output.
# &emsp;&emsp;`na_matches`: How should NA values be matched?
# &emsp;&emsp;&emsp;&emsp;"na": NA values are equal.
# &emsp;&emsp;&emsp;&emsp;"never": NA values are never matched.
#
# &emsp;&emsp;`multiple`: How should multiple matches be handled?
# &emsp;&emsp;&emsp;&emsp;"all": All matches are returned.
# &emsp;&emsp;&emsp;&emsp;"first": The first match is returned.
# &emsp;&emsp;&emsp;&emsp;"last": The last match is returned.
# &emsp;&emsp;&emsp;&emsp;"any": Any of the matched rows in y
#
# &emsp;&emsp;`unmatched`: How should unmatched keys that would result in dropped rows
# &emsp;&emsp;&emsp;&emsp;be handled?
# &emsp;&emsp;&emsp;&emsp;"drop": Drop unmatched keys.
# &emsp;&emsp;&emsp;&emsp;"error": Raise an error.
#
# &emsp;&emsp;`relationship`: The relationship between x and y.
# &emsp;&emsp;&emsp;&emsp;`None`: No expected relationship.
#
# &emsp;&emsp;&emsp;&emsp;"one_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"one_to_many": Each row in x matches zero or more rows in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_one": Each row in x matches at most one row in y.
# &emsp;&emsp;&emsp;&emsp;"many_to_many": Each row in x matches zero or more rows in y.
#
# ##### Returns:
# &emsp;&emsp;A data frame

# %%
band_members >> inner_join(band_instruments)
# Out:
# shape: (2, 3)
# ┌──────┬─────────┬────────┐
# │ name ┆ band    ┆ plays  │
# │ ---  ┆ ---     ┆ ---    │
# │ str  ┆ str     ┆ str    │
# ╞══════╪═════════╪════════╡
# │ John ┆ Beatles ┆ guitar │
# │ Paul ┆ Beatles ┆ bass   │
# └──────┴─────────┴────────┘

# %%
band_members >> left_join(band_instruments)
# Out:
# shape: (3, 3)
# ┌──────┬─────────┬────────┐
# │ name ┆ band    ┆ plays  │
# │ ---  ┆ ---     ┆ ---    │
# │ str  ┆ str     ┆ str    │
# ╞══════╪═════════╪════════╡
# │ Mick ┆ Stones  ┆ null   │
# │ John ┆ Beatles ┆ guitar │
# │ Paul ┆ Beatles ┆ bass   │
# └──────┴─────────┴────────┘

# %%
band_members >> right_join(band_instruments)
# Out:
# shape: (3, 3)
# ┌─────────┬───────┬────────┐
# │ band    ┆ name  ┆ plays  │
# │ ---     ┆ ---   ┆ ---    │
# │ str     ┆ str   ┆ str    │
# ╞═════════╪═══════╪════════╡
# │ Beatles ┆ John  ┆ guitar │
# │ Beatles ┆ Paul  ┆ bass   │
# │ null    ┆ Keith ┆ guitar │
# └─────────┴───────┴────────┘

# %%
band_members >> full_join(band_instruments)
# Out:
# shape: (4, 3)
# ┌───────┬─────────┬────────┐
# │ name  ┆ band    ┆ plays  │
# │ ---   ┆ ---     ┆ ---    │
# │ str   ┆ str     ┆ str    │
# ╞═══════╪═════════╪════════╡
# │ Mick  ┆ Stones  ┆ null   │
# │ John  ┆ Beatles ┆ guitar │
# │ Paul  ┆ Beatles ┆ bass   │
# │ Keith ┆ null    ┆ guitar │
# └───────┴─────────┴────────┘

# %%
band_members >> inner_join(band_instruments, by=f.name)
# Out:
# shape: (2, 3)
# ┌──────┬─────────┬────────┐
# │ name ┆ band    ┆ plays  │
# │ ---  ┆ ---     ┆ ---    │
# │ str  ┆ str     ┆ str    │
# ╞══════╪═════════╪════════╡
# │ John ┆ Beatles ┆ guitar │
# │ Paul ┆ Beatles ┆ bass   │
# └──────┴─────────┴────────┘

# %%
band_members >> full_join(band_instruments2, by={'name': 'artist'})
# Out:
# shape: (4, 3)
# ┌───────┬─────────┬────────┐
# │ name  ┆ band    ┆ plays  │
# │ ---   ┆ ---     ┆ ---    │
# │ str   ┆ str     ┆ str    │
# ╞═══════╪═════════╪════════╡
# │ Mick  ┆ Stones  ┆ null   │
# │ John  ┆ Beatles ┆ guitar │
# │ Paul  ┆ Beatles ┆ bass   │
# │ Keith ┆ null    ┆ guitar │
# └───────┴─────────┴────────┘

# %%
band_members >> full_join(band_instruments2, by={'name': 'artist'}, keep=True)
# Out:
# shape: (4, 3)
# ┌───────┬─────────┬────────┐
# │ name  ┆ band    ┆ plays  │
# │ ---   ┆ ---     ┆ ---    │
# │ str   ┆ str     ┆ str    │
# ╞═══════╪═════════╪════════╡
# │ Mick  ┆ Stones  ┆ null   │
# │ John  ┆ Beatles ┆ guitar │
# │ Paul  ┆ Beatles ┆ bass   │
# │ Keith ┆ null    ┆ guitar │
# └───────┴─────────┴────────┘

# %%
df1 = tibble(x=[1,2,3])
df2 = tibble(x=[1,1,2], y=["first", "second", "third"])
df1 >> left_join(df2)
# Out:
# shape: (4, 2)
# ┌─────┬────────┐
# │ x   ┆ y      │
# │ --- ┆ ---    │
# │ i64 ┆ str    │
# ╞═════╪════════╡
# │ 1   ┆ first  │
# │ 1   ┆ second │
# │ 2   ┆ third  │
# │ 3   ┆ null   │
# └─────┴────────┘

# %%
df1 = tibble(x=[1, NA], y=2)
df2 = tibble(x=[1, NA], z=3)
left_join(df1, df2) # na_matches not supported yet
# Out:
# shape: (2, 3)
# ┌─────┬─────┬─────┐
# │ x   ┆ y   ┆ z   │
# │ --- ┆ --- ┆ --- │
# │ f64 ┆ i64 ┆ i64 │
# ╞═════╪═════╪═════╡
# │ 1.0 ┆ 2   ┆ 3   │
# │ NaN ┆ 2   ┆ 3   │
# └─────┴─────┴─────┘
