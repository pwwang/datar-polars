# %%
# https://tidyr.tidyverse.org/reference/fill.html
# %run nb_helpers.py

from datar.all import *

nb_header(fill)
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Ffill.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ fill</div>
# ##### Fills missing values in selected columns using the next or
# previous entry.
#
# See https://tidyr.tidyverse.org/reference/fill.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A dataframe
# &emsp;&emsp;`*columns`: Columns to fill
# &emsp;&emsp;`_direction`: Direction in which to fill missing values.
# &emsp;&emsp;&emsp;&emsp;Currently either "down" (the default), "up",
# &emsp;&emsp;&emsp;&emsp;"downup" (i.e. first down and then up) or
# &emsp;&emsp;&emsp;&emsp;"updown" (first up and then down).
#
# ##### Returns:
# &emsp;&emsp;The dataframe with NAs being replaced.

# %%
sales = tribble(
  f.quarter, f.year, f.sales,
  "Q1",      2000,   66013,
  "Q2",        NA,   69182,
  "Q3",        NA,   53175,
  "Q4",        NA,   21001,
  "Q1",      2001,   46036,
  "Q2",        NA,   58842,
  "Q3",        NA,   44568,
  "Q4",        NA,   50197,
  "Q1",      2002,   39113,
  "Q2",        NA,   41668,
  "Q3",        NA,   30144,
  "Q4",        NA,   52897,
  "Q1",      2004,   32129,
  "Q2",        NA,   67686,
  "Q3",        NA,   31768,
  "Q4",        NA,   49094
)
sales
# Out:
# shape: (16, 3)
# ┌─────────┬────────┬───────┐
# │ quarter ┆ year   ┆ sales │
# │ ---     ┆ ---    ┆ ---   │
# │ str     ┆ f64    ┆ i64   │
# ╞═════════╪════════╪═══════╡
# │ Q1      ┆ 2000.0 ┆ 66013 │
# │ Q2      ┆ NaN    ┆ 69182 │
# │ Q3      ┆ NaN    ┆ 53175 │
# │ Q4      ┆ NaN    ┆ 21001 │
# │ Q1      ┆ 2001.0 ┆ 46036 │
# │ …       ┆ …      ┆ …     │
# │ Q4      ┆ NaN    ┆ 52897 │
# │ Q1      ┆ 2004.0 ┆ 32129 │
# │ Q2      ┆ NaN    ┆ 67686 │
# │ Q3      ┆ NaN    ┆ 31768 │
# │ Q4      ┆ NaN    ┆ 49094 │
# └─────────┴────────┴───────┘

# %%
sales >> fill(f.year)
# Out:
# shape: (16, 3)
# ┌─────────┬────────┬───────┐
# │ quarter ┆ year   ┆ sales │
# │ ---     ┆ ---    ┆ ---   │
# │ str     ┆ f64    ┆ i64   │
# ╞═════════╪════════╪═══════╡
# │ Q1      ┆ 2000.0 ┆ 66013 │
# │ Q2      ┆ 2000.0 ┆ 69182 │
# │ Q3      ┆ 2000.0 ┆ 53175 │
# │ Q4      ┆ 2000.0 ┆ 21001 │
# │ Q1      ┆ 2001.0 ┆ 46036 │
# │ …       ┆ …      ┆ …     │
# │ Q4      ┆ 2002.0 ┆ 52897 │
# │ Q1      ┆ 2004.0 ┆ 32129 │
# │ Q2      ┆ 2004.0 ┆ 67686 │
# │ Q3      ┆ 2004.0 ┆ 31768 │
# │ Q4      ┆ 2004.0 ┆ 49094 │
# └─────────┴────────┴───────┘

# %%
tidy_pets = tribble(
  f.rank,  f.pet_type, f.breed,
  1,          NA,      "Boston Terrier",
  2,          NA,      "Retrievers (Labrador)",
  3,          NA,      "Retrievers (Golden)",
  4,          NA,      "French Bulldogs",
  5,          NA,      "Bulldogs",
  6,       "Dog",      "Beagles",
  1,          NA,      "Persian",
  2,          NA,      "Maine Coon",
  3,          NA,      "Ragdoll",
  4,          NA,      "Exotic",
  5,          NA,      "Siamese",
  6,       "Cat",      "American Short"
)
tidy_pets >> fill(f.pet_type, _direction = "up")
# Out:
# shape: (12, 3)
# ┌──────┬──────────┬───────────────────────┐
# │ rank ┆ pet_type ┆ breed                 │
# │ ---  ┆ ---      ┆ ---                   │
# │ i64  ┆ str      ┆ str                   │
# ╞══════╪══════════╪═══════════════════════╡
# │ 1    ┆ Dog      ┆ Boston Terrier        │
# │ 2    ┆ Dog      ┆ Retrievers (Labrador) │
# │ 3    ┆ Dog      ┆ Retrievers (Golden)   │
# │ 4    ┆ Dog      ┆ French Bulldogs       │
# │ 5    ┆ Dog      ┆ Bulldogs              │
# │ …    ┆ …        ┆ …                     │
# │ 2    ┆ Cat      ┆ Maine Coon            │
# │ 3    ┆ Cat      ┆ Ragdoll               │
# │ 4    ┆ Cat      ┆ Exotic                │
# │ 5    ┆ Cat      ┆ Siamese               │
# │ 6    ┆ Cat      ┆ American Short        │
# └──────┴──────────┴───────────────────────┘

# %%
squirrels = tribble(
  f.group,    f.name,        f.role, f.n_squirrels,
  1,           "Sam",    "Observer",            NA,
  1,          "Mara", "Scorekeeper",             8,
  1,         "Jesse",    "Observer",            NA,
  1,           "Tom",    "Observer",            NA,
  2,          "Mike",    "Observer",            NA,
  2,       "Rachael",    "Observer",            NA,
  2,       "Sydekea", "Scorekeeper",            14,
  2,      "Gabriela",    "Observer",            NA,
  3,       "Derrick",    "Observer",            NA,
  3,          "Kara", "Scorekeeper",             9,
  3,         "Emily",    "Observer",            NA,
  3,      "Danielle",    "Observer",            NA
)

squirrels >> \
  group_by(f.group) >> \
  fill(f.n_squirrels, _direction = "downup")
# Out:
# shape: (12, 4)
# ┌───────┬──────────┬─────────────┬─────────────┐
# │ group ┆ name     ┆ role        ┆ n_squirrels │
# │ ---   ┆ ---      ┆ ---         ┆ ---         │
# │ i64   ┆ str      ┆ str         ┆ f64         │
# ╞═══════╪══════════╪═════════════╪═════════════╡
# │ 1     ┆ Sam      ┆ Observer    ┆ 8.0         │
# │ 1     ┆ Mara     ┆ Scorekeeper ┆ 8.0         │
# │ 1     ┆ Jesse    ┆ Observer    ┆ 8.0         │
# │ 1     ┆ Tom      ┆ Observer    ┆ 8.0         │
# │ 2     ┆ Mike     ┆ Observer    ┆ 14.0        │
# │ …     ┆ …        ┆ …           ┆ …           │
# │ 2     ┆ Gabriela ┆ Observer    ┆ 14.0        │
# │ 3     ┆ Derrick  ┆ Observer    ┆ 9.0         │
# │ 3     ┆ Kara     ┆ Scorekeeper ┆ 9.0         │
# │ 3     ┆ Emily    ┆ Observer    ┆ 9.0         │
# │ 3     ┆ Danielle ┆ Observer    ┆ 9.0         │
# └───────┴──────────┴─────────────┴─────────────┘
