# %%
# https://dplyr.tidyverse.org/reference/bind.html
# %run nb_helpers.py

from datar.data import starwars
from datar.all import *

nb_header(bind_rows, bind_cols, book='bind')
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Fbind.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ bind_rows</div>
# ##### Bind rows of give dataframes
#
# Original APIs https://dplyr.tidyverse.org/reference/bind.html
#
# ##### Args:
# &emsp;&emsp;`*data`: Dataframes to combine
# &emsp;&emsp;`_id`: The name of the id columns
# &emsp;&emsp;`_copy`: If `False`, do not copy data unnecessarily.
# &emsp;&emsp;&emsp;&emsp;Original API does not support this. This argument will be
# &emsp;&emsp;&emsp;&emsp;passed by to `pandas.concat()` as `copy` argument.
#
# &emsp;&emsp;`**kwargs`: A mapping of dataframe, keys will be used as _id col.
#
# ##### Returns:
# &emsp;&emsp;The combined dataframe
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ bind_cols</div>
# ##### Bind columns of give dataframes
#
# Note that unlike `dplyr`, mismatched dimensions are allowed and
# missing rows will be filled with `NA`s
#
# ##### Args:
# &emsp;&emsp;`*data`: Dataframes to bind
# &emsp;&emsp;`_name_repair`: treatment of problematic column names:
# &emsp;&emsp;&emsp;&emsp;- "minimal": No name repair or checks, beyond basic existence,
#
# &emsp;&emsp;&emsp;&emsp;- "unique": Make sure names are unique and not empty,
#
# &emsp;&emsp;&emsp;&emsp;- "check_unique": (default value), no name repair,
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;but check they are unique,
#
# &emsp;&emsp;&emsp;&emsp;- "universal": Make the names unique and syntactic
#
# &emsp;&emsp;&emsp;&emsp;- a function: apply custom name repair
#
# &emsp;&emsp;`_copy`: If `False`, do not copy data unnecessarily.
# &emsp;&emsp;&emsp;&emsp;Original API does not support this. This argument will be
# &emsp;&emsp;&emsp;&emsp;passed by to `pandas.concat()` as `copy` argument.
#
# ##### Returns:
# &emsp;&emsp;The combined dataframe

# %%
one = starwars >> slice(c[:4])
two = starwars >> slice(c[9:12])

one >> bind_rows(two)
# Out:
# shape: (7, 11)
# ┌──────────────────┬────────┬───────┬───────────────┬───┬──────┬───────────┬───────────┬─────────┐
# │ name             ┆ height ┆ mass  ┆ hair_color    ┆ … ┆ sex  ┆ gender    ┆ homeworld ┆ species │
# │ ---              ┆ ---    ┆ ---   ┆ ---           ┆   ┆ ---  ┆ ---       ┆ ---       ┆ ---     │
# │ str              ┆ i64    ┆ f64   ┆ str           ┆   ┆ str  ┆ str       ┆ str       ┆ str     │
# ╞══════════════════╪════════╪═══════╪═══════════════╪═══╪══════╪═══════════╪═══════════╪═════════╡
# │ Luke Skywalker   ┆ 172    ┆ 77.0  ┆ blond         ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ C-3PO            ┆ 167    ┆ 75.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Tatooine  ┆ Droid   │
# │ R2-D2            ┆ 96     ┆ 32.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Naboo     ┆ Droid   │
# │ Darth Vader      ┆ 202    ┆ 136.0 ┆ none          ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Obi-Wan Kenobi   ┆ 182    ┆ 77.0  ┆ auburn, white ┆ … ┆ male ┆ masculine ┆ Stewjon   ┆ Human   │
# │ Anakin Skywalker ┆ 188    ┆ 84.0  ┆ blond         ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Wilhuff Tarkin   ┆ 180    ┆ null  ┆ auburn, grey  ┆ … ┆ male ┆ masculine ┆ Eriadu    ┆ Human   │
# └──────────────────┴────────┴───────┴───────────────┴───┴──────┴───────────┴───────────┴─────────┘

# %%
bind_rows([one, two])
# Out:
# shape: (7, 11)
# ┌──────────────────┬────────┬───────┬───────────────┬───┬──────┬───────────┬───────────┬─────────┐
# │ name             ┆ height ┆ mass  ┆ hair_color    ┆ … ┆ sex  ┆ gender    ┆ homeworld ┆ species │
# │ ---              ┆ ---    ┆ ---   ┆ ---           ┆   ┆ ---  ┆ ---       ┆ ---       ┆ ---     │
# │ str              ┆ i64    ┆ f64   ┆ str           ┆   ┆ str  ┆ str       ┆ str       ┆ str     │
# ╞══════════════════╪════════╪═══════╪═══════════════╪═══╪══════╪═══════════╪═══════════╪═════════╡
# │ Luke Skywalker   ┆ 172    ┆ 77.0  ┆ blond         ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ C-3PO            ┆ 167    ┆ 75.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Tatooine  ┆ Droid   │
# │ R2-D2            ┆ 96     ┆ 32.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Naboo     ┆ Droid   │
# │ Darth Vader      ┆ 202    ┆ 136.0 ┆ none          ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Obi-Wan Kenobi   ┆ 182    ┆ 77.0  ┆ auburn, white ┆ … ┆ male ┆ masculine ┆ Stewjon   ┆ Human   │
# │ Anakin Skywalker ┆ 188    ┆ 84.0  ┆ blond         ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Wilhuff Tarkin   ┆ 180    ┆ null  ┆ auburn, grey  ┆ … ┆ male ┆ masculine ┆ Eriadu    ┆ Human   │
# └──────────────────┴────────┴───────┴───────────────┴───┴──────┴───────────┴───────────┴─────────┘

# %%
bind_rows([one, two], [two, one])
# Out:
# shape: (14, 11)
# ┌────────────────┬────────┬───────┬───────────────┬───┬──────┬───────────┬───────────┬─────────┐
# │ name           ┆ height ┆ mass  ┆ hair_color    ┆ … ┆ sex  ┆ gender    ┆ homeworld ┆ species │
# │ ---            ┆ ---    ┆ ---   ┆ ---           ┆   ┆ ---  ┆ ---       ┆ ---       ┆ ---     │
# │ str            ┆ i64    ┆ f64   ┆ str           ┆   ┆ str  ┆ str       ┆ str       ┆ str     │
# ╞════════════════╪════════╪═══════╪═══════════════╪═══╪══════╪═══════════╪═══════════╪═════════╡
# │ Luke Skywalker ┆ 172    ┆ 77.0  ┆ blond         ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ C-3PO          ┆ 167    ┆ 75.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Tatooine  ┆ Droid   │
# │ R2-D2          ┆ 96     ┆ 32.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Naboo     ┆ Droid   │
# │ Darth Vader    ┆ 202    ┆ 136.0 ┆ none          ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Obi-Wan Kenobi ┆ 182    ┆ 77.0  ┆ auburn, white ┆ … ┆ male ┆ masculine ┆ Stewjon   ┆ Human   │
# │ …              ┆ …      ┆ …     ┆ …             ┆ … ┆ …    ┆ …         ┆ …         ┆ …       │
# │ Wilhuff Tarkin ┆ 180    ┆ null  ┆ auburn, grey  ┆ … ┆ male ┆ masculine ┆ Eriadu    ┆ Human   │
# │ Luke Skywalker ┆ 172    ┆ 77.0  ┆ blond         ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# │ C-3PO          ┆ 167    ┆ 75.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Tatooine  ┆ Droid   │
# │ R2-D2          ┆ 96     ┆ 32.0  ┆ null          ┆ … ┆ none ┆ masculine ┆ Naboo     ┆ Droid   │
# │ Darth Vader    ┆ 202    ┆ 136.0 ┆ none          ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human   │
# └────────────────┴────────┴───────┴───────────────┴───┴──────┴───────────┴───────────┴─────────┘

# %%
tibble(a=1, b=2) >> bind_rows(tibble(a=3, b=4))
# Out:
# shape: (2, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 2   │
# │ 3   ┆ 4   │
# └─────┴─────┘

# %%
tibble(a=1, b=2) >> bind_rows(
    tibble(a=[3, 4], b=[5, 6]),
    tibble(a=7, b=8)
)
# Out:
# shape: (4, 2)
# ┌─────┬─────┐
# │ a   ┆ b   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 2   │
# │ 3   ┆ 5   │
# │ 4   ┆ 6   │
# │ 7   ┆ 8   │
# └─────┴─────┘

# %%
bind_rows([one, two], _id = "id")
# Out:
# shape: (7, 12)
# ┌──────────────────┬────────┬───────┬───────────────┬───┬───────────┬───────────┬─────────┬─────┐
# │ name             ┆ height ┆ mass  ┆ hair_color    ┆ … ┆ gender    ┆ homeworld ┆ species ┆ id  │
# │ ---              ┆ ---    ┆ ---   ┆ ---           ┆   ┆ ---       ┆ ---       ┆ ---     ┆ --- │
# │ str              ┆ i64    ┆ f64   ┆ str           ┆   ┆ str       ┆ str       ┆ str     ┆ i32 │
# ╞══════════════════╪════════╪═══════╪═══════════════╪═══╪═══════════╪═══════════╪═════════╪═════╡
# │ Luke Skywalker   ┆ 172    ┆ 77.0  ┆ blond         ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ 0   │
# │ C-3PO            ┆ 167    ┆ 75.0  ┆ null          ┆ … ┆ masculine ┆ Tatooine  ┆ Droid   ┆ 0   │
# │ R2-D2            ┆ 96     ┆ 32.0  ┆ null          ┆ … ┆ masculine ┆ Naboo     ┆ Droid   ┆ 0   │
# │ Darth Vader      ┆ 202    ┆ 136.0 ┆ none          ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ 0   │
# │ Obi-Wan Kenobi   ┆ 182    ┆ 77.0  ┆ auburn, white ┆ … ┆ masculine ┆ Stewjon   ┆ Human   ┆ 1   │
# │ Anakin Skywalker ┆ 188    ┆ 84.0  ┆ blond         ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ 1   │
# │ Wilhuff Tarkin   ┆ 180    ┆ null  ┆ auburn, grey  ┆ … ┆ masculine ┆ Eriadu    ┆ Human   ┆ 1   │
# └──────────────────┴────────┴───────┴───────────────┴───┴───────────┴───────────┴─────────┴─────┘

# %%
# If we need a name for one
bind_rows(a=one, b=two, _id = "id")
# Out:
# shape: (7, 12)
# ┌──────────────────┬────────┬───────┬───────────────┬───┬───────────┬───────────┬─────────┬─────┐
# │ name             ┆ height ┆ mass  ┆ hair_color    ┆ … ┆ gender    ┆ homeworld ┆ species ┆ id  │
# │ ---              ┆ ---    ┆ ---   ┆ ---           ┆   ┆ ---       ┆ ---       ┆ ---     ┆ --- │
# │ str              ┆ i64    ┆ f64   ┆ str           ┆   ┆ str       ┆ str       ┆ str     ┆ str │
# ╞══════════════════╪════════╪═══════╪═══════════════╪═══╪═══════════╪═══════════╪═════════╪═════╡
# │ Luke Skywalker   ┆ 172    ┆ 77.0  ┆ blond         ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ a   │
# │ C-3PO            ┆ 167    ┆ 75.0  ┆ null          ┆ … ┆ masculine ┆ Tatooine  ┆ Droid   ┆ a   │
# │ R2-D2            ┆ 96     ┆ 32.0  ┆ null          ┆ … ┆ masculine ┆ Naboo     ┆ Droid   ┆ a   │
# │ Darth Vader      ┆ 202    ┆ 136.0 ┆ none          ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ a   │
# │ Obi-Wan Kenobi   ┆ 182    ┆ 77.0  ┆ auburn, white ┆ … ┆ masculine ┆ Stewjon   ┆ Human   ┆ b   │
# │ Anakin Skywalker ┆ 188    ┆ 84.0  ┆ blond         ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ b   │
# │ Wilhuff Tarkin   ┆ 180    ┆ null  ┆ auburn, grey  ┆ … ┆ masculine ┆ Eriadu    ┆ Human   ┆ b   │
# └──────────────────┴────────┴───────┴───────────────┴───┴───────────┴───────────┴─────────┴─────┘

# %%
bind_rows(**{"group 1": one, "group 2": two}, _id = "groups")
# Out:
# shape: (7, 12)
# ┌─────────────────┬────────┬───────┬───────────────┬───┬───────────┬───────────┬─────────┬─────────┐
# │ name            ┆ height ┆ mass  ┆ hair_color    ┆ … ┆ gender    ┆ homeworld ┆ species ┆ groups  │
# │ ---             ┆ ---    ┆ ---   ┆ ---           ┆   ┆ ---       ┆ ---       ┆ ---     ┆ ---     │
# │ str             ┆ i64    ┆ f64   ┆ str           ┆   ┆ str       ┆ str       ┆ str     ┆ str     │
# ╞═════════════════╪════════╪═══════╪═══════════════╪═══╪═══════════╪═══════════╪═════════╪═════════╡
# │ Luke Skywalker  ┆ 172    ┆ 77.0  ┆ blond         ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ group 1 │
# │ C-3PO           ┆ 167    ┆ 75.0  ┆ null          ┆ … ┆ masculine ┆ Tatooine  ┆ Droid   ┆ group 1 │
# │ R2-D2           ┆ 96     ┆ 32.0  ┆ null          ┆ … ┆ masculine ┆ Naboo     ┆ Droid   ┆ group 1 │
# │ Darth Vader     ┆ 202    ┆ 136.0 ┆ none          ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ group 1 │
# │ Obi-Wan Kenobi  ┆ 182    ┆ 77.0  ┆ auburn, white ┆ … ┆ masculine ┆ Stewjon   ┆ Human   ┆ group 2 │
# │ Anakin          ┆ 188    ┆ 84.0  ┆ blond         ┆ … ┆ masculine ┆ Tatooine  ┆ Human   ┆ group 2 │
# │ Skywalker       ┆        ┆       ┆               ┆   ┆           ┆           ┆         ┆         │
# │ Wilhuff Tarkin  ┆ 180    ┆ null  ┆ auburn, grey  ┆ … ┆ masculine ┆ Eriadu    ┆ Human   ┆ group 2 │
# └─────────────────┴────────┴───────┴───────────────┴───┴───────────┴───────────┴─────────┴─────────┘

# %%
tibble(x=range(3)) >> bind_rows(
    tibble(y=range(4))
)
# Out:
# shape: (7, 2)
# ┌──────┬──────┐
# │ x    ┆ y    │
# │ ---  ┆ ---  │
# │ i64  ┆ i64  │
# ╞══════╪══════╡
# │ 0    ┆ null │
# │ 1    ┆ null │
# │ 2    ┆ null │
# │ null ┆ 0    │
# │ null ┆ 1    │
# │ null ┆ 2    │
# │ null ┆ 3    │
# └──────┴──────┘

# %%
# NAs filled for missed rows
tibble(x=range(3)) >> bind_cols(
    tibble(y=range(2))
)
# Out:
# shape: (3, 2)
# ┌─────┬──────┐
# │ x   ┆ y    │
# │ --- ┆ ---  │
# │ i64 ┆ i64  │
# ╞═════╪══════╡
# │ 0   ┆ 0    │
# │ 1   ┆ 1    │
# │ 2   ┆ null │
# └─────┴──────┘

# %%
tibble(x = range(3)) >> bind_cols(tibble())
# Out:
# shape: (3, 1)
# ┌─────┐
# │ x   │
# │ --- │
# │ i64 │
# ╞═════╡
# │ 0   │
# │ 1   │
# │ 2   │
# └─────┘

# %%
one >> bind_cols(two)
# Out:
# [2026-05-04 17:40:49][datar][WARNING] New names:
# [2026-05-04 17:40:49][datar][WARNING] * 'name' -> 'name__0'
# [2026-05-04 17:40:49][datar][WARNING] * 'height' -> 'height__1'
# [2026-05-04 17:40:49][datar][WARNING] * 'mass' -> 'mass__2'
# [2026-05-04 17:40:49][datar][WARNING] * 'hair_color' -> 'hair_color__3'
# [2026-05-04 17:40:49][datar][WARNING] * 'skin_color' -> 'skin_color__4'
# [2026-05-04 17:40:49][datar][WARNING] * 'eye_color' -> 'eye_color__5'
# [2026-05-04 17:40:49][datar][WARNING] * 'birth_year' -> 'birth_year__6'
# [2026-05-04 17:40:49][datar][WARNING] * 'sex' -> 'sex__7'
# [2026-05-04 17:40:49][datar][WARNING] * 'gender' -> 'gender__8'
# [2026-05-04 17:40:49][datar][WARNING] * 'homeworld' -> 'homeworld__9'
# [2026-05-04 17:40:49][datar][WARNING] * 'species' -> 'species__10'
# [2026-05-04 17:40:49][datar][WARNING] * 'name' -> 'name__11'
# [2026-05-04 17:40:49][datar][WARNING] * 'height' -> 'height__12'
# [2026-05-04 17:40:49][datar][WARNING] * 'mass' -> 'mass__13'
# [2026-05-04 17:40:49][datar][WARNING] * 'hair_color' -> 'hair_color__14'
# [2026-05-04 17:40:49][datar][WARNING] * 'skin_color' -> 'skin_color__15'
# [2026-05-04 17:40:49][datar][WARNING] * 'eye_color' -> 'eye_color__16'
# [2026-05-04 17:40:49][datar][WARNING] * 'birth_year' -> 'birth_year__17'
# [2026-05-04 17:40:49][datar][WARNING] * 'sex' -> 'sex__18'
# [2026-05-04 17:40:49][datar][WARNING] * 'gender' -> 'gender__19'
# [2026-05-04 17:40:49][datar][WARNING] * 'homeworld' -> 'homeworld__20'
# [2026-05-04 17:40:49][datar][WARNING] * 'species' -> 'species__21'
# shape: (4, 22)
# ┌────────────┬───────────┬─────────┬────────────┬───┬─────────┬────────────┬───────────┬───────────┐
# │ name__0    ┆ height__1 ┆ mass__2 ┆ hair_color ┆ … ┆ sex__18 ┆ gender__19 ┆ homeworld ┆ species__ │
# │ ---        ┆ ---       ┆ ---     ┆ __3        ┆   ┆ ---     ┆ ---        ┆ __20      ┆ 21        │
# │ str        ┆ i64       ┆ f64     ┆ ---        ┆   ┆ str     ┆ str        ┆ ---       ┆ ---       │
# │            ┆           ┆         ┆ str        ┆   ┆         ┆            ┆ str       ┆ str       │
# ╞════════════╪═══════════╪═════════╪════════════╪═══╪═════════╪════════════╪═══════════╪═══════════╡
# │ Luke       ┆ 172       ┆ 77.0    ┆ blond      ┆ … ┆ male    ┆ masculine  ┆ Stewjon   ┆ Human     │
# │ Skywalker  ┆           ┆         ┆            ┆   ┆         ┆            ┆           ┆           │
# │ C-3PO      ┆ 167       ┆ 75.0    ┆ null       ┆ … ┆ male    ┆ masculine  ┆ Tatooine  ┆ Human     │
# │ R2-D2      ┆ 96        ┆ 32.0    ┆ null       ┆ … ┆ male    ┆ masculine  ┆ Eriadu    ┆ Human     │
# │ Darth      ┆ 202       ┆ 136.0   ┆ none       ┆ … ┆ null    ┆ null       ┆ null      ┆ null      │
# │ Vader      ┆           ┆         ┆            ┆   ┆         ┆            ┆           ┆           │
# └────────────┴───────────┴─────────┴────────────┴───┴─────────┴────────────┴───────────┴───────────┘
