# %%
# https://dplyr.tidyverse.org/reference/filter.html
# %run nb_helpers.py
from datar.data import starwars
from datar.all import *

nb_header(filter)
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Ffilter_.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ filter_</div>
# ##### Filter a data frame based on conditions
#
# The original API:
# https://dplyr.tidyverse.org/reference/filter.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`*conditions`: Conditions to filter by.
# &emsp;&emsp;`_preserve`: If `True`, keep grouping variables even if they are not used.
#
# ##### Returns:
# &emsp;&emsp;The subset dataframe

# %%
filter(starwars, f.species == "Human")
# Out:
# shape: (35, 11)
# ┌────────────────────┬────────┬───────┬─────────────┬───┬────────┬───────────┬───────────┬─────────┐
# │ name               ┆ height ┆ mass  ┆ hair_color  ┆ … ┆ sex    ┆ gender    ┆ homeworld ┆ species │
# │ ---                ┆ ---    ┆ ---   ┆ ---         ┆   ┆ ---    ┆ ---       ┆ ---       ┆ ---     │
# │ str                ┆ i64    ┆ f64   ┆ str         ┆   ┆ str    ┆ str       ┆ str       ┆ str     │
# ╞════════════════════╪════════╪═══════╪═════════════╪═══╪════════╪═══════════╪═══════════╪═════════╡
# │ Luke Skywalker     ┆ 172    ┆ 77.0  ┆ blond       ┆ … ┆ male   ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Darth Vader        ┆ 202    ┆ 136.0 ┆ none        ┆ … ┆ male   ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Leia Organa        ┆ 150    ┆ 49.0  ┆ brown       ┆ … ┆ female ┆ feminine  ┆ Alderaan  ┆ Human   │
# │ Owen Lars          ┆ 178    ┆ 120.0 ┆ brown, grey ┆ … ┆ male   ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Beru Whitesun lars ┆ 165    ┆ 75.0  ┆ brown       ┆ … ┆ female ┆ feminine  ┆ Tatooine  ┆ Human   │
# │ …                  ┆ …      ┆ …     ┆ …           ┆ … ┆ …      ┆ …         ┆ …         ┆ …       │
# │ Raymus Antilles    ┆ 188    ┆ 79.0  ┆ brown       ┆ … ┆ male   ┆ masculine ┆ Alderaan  ┆ Human   │
# │ Finn               ┆ null   ┆ null  ┆ black       ┆ … ┆ male   ┆ masculine ┆ null      ┆ Human   │
# │ Rey                ┆ null   ┆ null  ┆ brown       ┆ … ┆ female ┆ feminine  ┆ null      ┆ Human   │
# │ Poe Dameron        ┆ null   ┆ null  ┆ brown       ┆ … ┆ male   ┆ masculine ┆ null      ┆ Human   │
# │ Padmé Amidala      ┆ 165    ┆ 45.0  ┆ brown       ┆ … ┆ female ┆ feminine  ┆ Naboo     ┆ Human   │
# └────────────────────┴────────┴───────┴─────────────┴───┴────────┴───────────┴───────────┴─────────┘

# %%
filter(starwars, f.mass > 1000)
# Out:
# shape: (1, 11)
# ┌───────────┬────────┬────────┬────────────┬───┬─────────────────┬───────────┬───────────┬─────────┐
# │ name      ┆ height ┆ mass   ┆ hair_color ┆ … ┆ sex             ┆ gender    ┆ homeworld ┆ species │
# │ ---       ┆ ---    ┆ ---    ┆ ---        ┆   ┆ ---             ┆ ---       ┆ ---       ┆ ---     │
# │ str       ┆ i64    ┆ f64    ┆ str        ┆   ┆ str             ┆ str       ┆ str       ┆ str     │
# ╞═══════════╪════════╪════════╪════════════╪═══╪═════════════════╪═══════════╪═══════════╪═════════╡
# │ Jabba     ┆ 175    ┆ 1358.0 ┆ null       ┆ … ┆ hermaphroditic  ┆ masculine ┆ Nal Hutta ┆ Hutt    │
# │ Desilijic ┆        ┆        ┆            ┆   ┆                 ┆           ┆           ┆         │
# │ Tiure     ┆        ┆        ┆            ┆   ┆                 ┆           ┆           ┆         │
# └───────────┴────────┴────────┴────────────┴───┴─────────────────┴───────────┴───────────┴─────────┘

# %%
# Conditions connected by & or | have to wrapped, since == has lower priority than & does
filter(starwars, (f.hair_color == "none") & (f.eye_color == "black"))
# Out:
# shape: (9, 11)
# ┌────────────┬────────┬──────┬────────────┬───┬────────┬───────────┬─────────────┬───────────┐
# │ name       ┆ height ┆ mass ┆ hair_color ┆ … ┆ sex    ┆ gender    ┆ homeworld   ┆ species   │
# │ ---        ┆ ---    ┆ ---  ┆ ---        ┆   ┆ ---    ┆ ---       ┆ ---         ┆ ---       │
# │ str        ┆ i64    ┆ f64  ┆ str        ┆   ┆ str    ┆ str       ┆ str         ┆ str       │
# ╞════════════╪════════╪══════╪════════════╪═══╪════════╪═══════════╪═════════════╪═══════════╡
# │ Nien Nunb  ┆ 160    ┆ 68.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Sullust     ┆ Sullustan │
# │ Gasgano    ┆ 122    ┆ null ┆ none       ┆ … ┆ male   ┆ masculine ┆ Troiken     ┆ Xexto     │
# │ Kit Fisto  ┆ 196    ┆ 87.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Glee Anselm ┆ Nautolan  │
# │ Plo Koon   ┆ 188    ┆ 80.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Dorin       ┆ Kel Dor   │
# │ Lama Su    ┆ 229    ┆ 88.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Kamino      ┆ Kaminoan  │
# │ Taun We    ┆ 213    ┆ null ┆ none       ┆ … ┆ female ┆ feminine  ┆ Kamino      ┆ Kaminoan  │
# │ Shaak Ti   ┆ 178    ┆ 57.0 ┆ none       ┆ … ┆ female ┆ feminine  ┆ Shili       ┆ Togruta   │
# │ Tion Medon ┆ 206    ┆ 80.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Utapau      ┆ Pau'an    │
# │ BB8        ┆ null   ┆ null ┆ none       ┆ … ┆ none   ┆ masculine ┆ null        ┆ Droid     │
# └────────────┴────────┴──────┴────────────┴───┴────────┴───────────┴─────────────┴───────────┘

# %%
filter(starwars, (f.hair_color == "none") | (f.eye_color == "black"))
# Out:
# shape: (38, 11)
# ┌─────────────┬────────┬───────┬────────────┬───┬────────┬───────────┬───────────┬────────────┐
# │ name        ┆ height ┆ mass  ┆ hair_color ┆ … ┆ sex    ┆ gender    ┆ homeworld ┆ species    │
# │ ---         ┆ ---    ┆ ---   ┆ ---        ┆   ┆ ---    ┆ ---       ┆ ---       ┆ ---        │
# │ str         ┆ i64    ┆ f64   ┆ str        ┆   ┆ str    ┆ str       ┆ str       ┆ str        │
# ╞═════════════╪════════╪═══════╪════════════╪═══╪════════╪═══════════╪═══════════╪════════════╡
# │ Darth Vader ┆ 202    ┆ 136.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Tatooine  ┆ Human      │
# │ Greedo      ┆ 173    ┆ 74.0  ┆ null       ┆ … ┆ male   ┆ masculine ┆ Rodia     ┆ Rodian     │
# │ IG-88       ┆ 200    ┆ 140.0 ┆ none       ┆ … ┆ none   ┆ masculine ┆ null      ┆ Droid      │
# │ Bossk       ┆ 190    ┆ 113.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Trandosha ┆ Trandoshan │
# │ Lobot       ┆ 175    ┆ 79.0  ┆ none       ┆ … ┆ male   ┆ masculine ┆ Bespin    ┆ Human      │
# │ …           ┆ …      ┆ …     ┆ …          ┆ … ┆ …      ┆ …         ┆ …         ┆ …          │
# │ Shaak Ti    ┆ 178    ┆ 57.0  ┆ none       ┆ … ┆ female ┆ feminine  ┆ Shili     ┆ Togruta    │
# │ Grievous    ┆ 216    ┆ 159.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Kalee     ┆ Kaleesh    │
# │ Sly Moore   ┆ 178    ┆ 48.0  ┆ none       ┆ … ┆ null   ┆ null      ┆ Umbara    ┆ null       │
# │ Tion Medon  ┆ 206    ┆ 80.0  ┆ none       ┆ … ┆ male   ┆ masculine ┆ Utapau    ┆ Pau'an     │
# │ BB8         ┆ null   ┆ null  ┆ none       ┆ … ┆ none   ┆ masculine ┆ null      ┆ Droid      │
# └─────────────┴────────┴───────┴────────────┴───┴────────┴───────────┴───────────┴────────────┘

# %%
filter(starwars, f.hair_color == "none", f.eye_color == "black")
# Out:
# shape: (9, 11)
# ┌────────────┬────────┬──────┬────────────┬───┬────────┬───────────┬─────────────┬───────────┐
# │ name       ┆ height ┆ mass ┆ hair_color ┆ … ┆ sex    ┆ gender    ┆ homeworld   ┆ species   │
# │ ---        ┆ ---    ┆ ---  ┆ ---        ┆   ┆ ---    ┆ ---       ┆ ---         ┆ ---       │
# │ str        ┆ i64    ┆ f64  ┆ str        ┆   ┆ str    ┆ str       ┆ str         ┆ str       │
# ╞════════════╪════════╪══════╪════════════╪═══╪════════╪═══════════╪═════════════╪═══════════╡
# │ Nien Nunb  ┆ 160    ┆ 68.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Sullust     ┆ Sullustan │
# │ Gasgano    ┆ 122    ┆ null ┆ none       ┆ … ┆ male   ┆ masculine ┆ Troiken     ┆ Xexto     │
# │ Kit Fisto  ┆ 196    ┆ 87.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Glee Anselm ┆ Nautolan  │
# │ Plo Koon   ┆ 188    ┆ 80.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Dorin       ┆ Kel Dor   │
# │ Lama Su    ┆ 229    ┆ 88.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Kamino      ┆ Kaminoan  │
# │ Taun We    ┆ 213    ┆ null ┆ none       ┆ … ┆ female ┆ feminine  ┆ Kamino      ┆ Kaminoan  │
# │ Shaak Ti   ┆ 178    ┆ 57.0 ┆ none       ┆ … ┆ female ┆ feminine  ┆ Shili       ┆ Togruta   │
# │ Tion Medon ┆ 206    ┆ 80.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Utapau      ┆ Pau'an    │
# │ BB8        ┆ null   ┆ null ┆ none       ┆ … ┆ none   ┆ masculine ┆ null        ┆ Droid     │
# └────────────┴────────┴──────┴────────────┴───┴────────┴───────────┴─────────────┴───────────┘

# %%
starwars >> filter(f.mass > mean(f.mass))
# Out:
# shape: (10, 11)
# ┌────────────┬────────┬────────┬────────────┬───┬────────────┬───────────┬────────────┬────────────┐
# │ name       ┆ height ┆ mass   ┆ hair_color ┆ … ┆ sex        ┆ gender    ┆ homeworld  ┆ species    │
# │ ---        ┆ ---    ┆ ---    ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---        ┆ ---        │
# │ str        ┆ i64    ┆ f64    ┆ str        ┆   ┆ str        ┆ str       ┆ str        ┆ str        │
# ╞════════════╪════════╪════════╪════════════╪═══╪════════════╪═══════════╪════════════╪════════════╡
# │ Darth      ┆ 202    ┆ 136.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Tatooine   ┆ Human      │
# │ Vader      ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ Owen Lars  ┆ 178    ┆ 120.0  ┆ brown,     ┆ … ┆ male       ┆ masculine ┆ Tatooine   ┆ Human      │
# │            ┆        ┆        ┆ grey       ┆   ┆            ┆           ┆            ┆            │
# │ Chewbacca  ┆ 228    ┆ 112.0  ┆ brown      ┆ … ┆ male       ┆ masculine ┆ Kashyyyk   ┆ Wookiee    │
# │ Jabba      ┆ 175    ┆ 1358.0 ┆ null       ┆ … ┆ hermaphrod ┆ masculine ┆ Nal Hutta  ┆ Hutt       │
# │ Desilijic  ┆        ┆        ┆            ┆   ┆ itic       ┆           ┆            ┆            │
# │ Tiure      ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ Jek Tono   ┆ 180    ┆ 110.0  ┆ brown      ┆ … ┆ male       ┆ masculine ┆ Bestine IV ┆ Human      │
# │ Porkins    ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ IG-88      ┆ 200    ┆ 140.0  ┆ none       ┆ … ┆ none       ┆ masculine ┆ null       ┆ Droid      │
# │ Bossk      ┆ 190    ┆ 113.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Trandosha  ┆ Trandoshan │
# │ Dexter     ┆ 198    ┆ 102.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Ojom       ┆ Besalisk   │
# │ Jettster   ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ Grievous   ┆ 216    ┆ 159.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Kalee      ┆ Kaleesh    │
# │ Tarfful    ┆ 234    ┆ 136.0  ┆ brown      ┆ … ┆ male       ┆ masculine ┆ Kashyyyk   ┆ Wookiee    │
# └────────────┴────────┴────────┴────────────┴───┴────────────┴───────────┴────────────┴────────────┘

# %%
starwars >> group_by(f.gender) >> filter_(f.mass > mean(f.mass))
# Out:
# shape: (10, 11)
# ┌────────────┬────────┬────────┬────────────┬───┬────────────┬───────────┬────────────┬────────────┐
# │ name       ┆ height ┆ mass   ┆ hair_color ┆ … ┆ sex        ┆ gender    ┆ homeworld  ┆ species    │
# │ ---        ┆ ---    ┆ ---    ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---        ┆ ---        │
# │ str        ┆ i64    ┆ f64    ┆ str        ┆   ┆ str        ┆ str       ┆ str        ┆ str        │
# ╞════════════╪════════╪════════╪════════════╪═══╪════════════╪═══════════╪════════════╪════════════╡
# │ Darth      ┆ 202    ┆ 136.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Tatooine   ┆ Human      │
# │ Vader      ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ Owen Lars  ┆ 178    ┆ 120.0  ┆ brown,     ┆ … ┆ male       ┆ masculine ┆ Tatooine   ┆ Human      │
# │            ┆        ┆        ┆ grey       ┆   ┆            ┆           ┆            ┆            │
# │ Chewbacca  ┆ 228    ┆ 112.0  ┆ brown      ┆ … ┆ male       ┆ masculine ┆ Kashyyyk   ┆ Wookiee    │
# │ Jabba      ┆ 175    ┆ 1358.0 ┆ null       ┆ … ┆ hermaphrod ┆ masculine ┆ Nal Hutta  ┆ Hutt       │
# │ Desilijic  ┆        ┆        ┆            ┆   ┆ itic       ┆           ┆            ┆            │
# │ Tiure      ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ Jek Tono   ┆ 180    ┆ 110.0  ┆ brown      ┆ … ┆ male       ┆ masculine ┆ Bestine IV ┆ Human      │
# │ Porkins    ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ IG-88      ┆ 200    ┆ 140.0  ┆ none       ┆ … ┆ none       ┆ masculine ┆ null       ┆ Droid      │
# │ Bossk      ┆ 190    ┆ 113.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Trandosha  ┆ Trandoshan │
# │ Dexter     ┆ 198    ┆ 102.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Ojom       ┆ Besalisk   │
# │ Jettster   ┆        ┆        ┆            ┆   ┆            ┆           ┆            ┆            │
# │ Grievous   ┆ 216    ┆ 159.0  ┆ none       ┆ … ┆ male       ┆ masculine ┆ Kalee      ┆ Kaleesh    │
# │ Tarfful    ┆ 234    ┆ 136.0  ┆ brown      ┆ … ┆ male       ┆ masculine ┆ Kashyyyk   ┆ Wookiee    │
# └────────────┴────────┴────────┴────────────┴───┴────────────┴───────────┴────────────┴────────────┘

# %%
# To refer to column names that are stored as strings, use `f[...]`:
vars = c("mass", "height")
cond = c(80, 150)
starwars >> \
  filter(
    f[vars[0]] > cond[0],
    f[vars[1]] > cond[1]
  )
# Out:
# shape: (21, 11)
# ┌───────────────────┬────────┬───────┬─────────────┬───┬──────┬───────────┬───────────┬──────────┐
# │ name              ┆ height ┆ mass  ┆ hair_color  ┆ … ┆ sex  ┆ gender    ┆ homeworld ┆ species  │
# │ ---               ┆ ---    ┆ ---   ┆ ---         ┆   ┆ ---  ┆ ---       ┆ ---       ┆ ---      │
# │ str               ┆ i64    ┆ f64   ┆ str         ┆   ┆ str  ┆ str       ┆ str       ┆ str      │
# ╞═══════════════════╪════════╪═══════╪═════════════╪═══╪══════╪═══════════╪═══════════╪══════════╡
# │ Darth Vader       ┆ 202    ┆ 136.0 ┆ none        ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human    │
# │ Owen Lars         ┆ 178    ┆ 120.0 ┆ brown, grey ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human    │
# │ Biggs Darklighter ┆ 183    ┆ 84.0  ┆ black       ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human    │
# │ Anakin Skywalker  ┆ 188    ┆ 84.0  ┆ blond       ┆ … ┆ male ┆ masculine ┆ Tatooine  ┆ Human    │
# │ Chewbacca         ┆ 228    ┆ 112.0 ┆ brown       ┆ … ┆ male ┆ masculine ┆ Kashyyyk  ┆ Wookiee  │
# │ …                 ┆ …      ┆ …     ┆ …           ┆ … ┆ …    ┆ …         ┆ …         ┆ …        │
# │ Gregar Typho      ┆ 185    ┆ 85.0  ┆ black       ┆ … ┆ male ┆ masculine ┆ Naboo     ┆ Human    │
# │ Dexter Jettster   ┆ 198    ┆ 102.0 ┆ none        ┆ … ┆ male ┆ masculine ┆ Ojom      ┆ Besalisk │
# │ Lama Su           ┆ 229    ┆ 88.0  ┆ none        ┆ … ┆ male ┆ masculine ┆ Kamino    ┆ Kaminoan │
# │ Grievous          ┆ 216    ┆ 159.0 ┆ none        ┆ … ┆ male ┆ masculine ┆ Kalee     ┆ Kaleesh  │
# │ Tarfful           ┆ 234    ┆ 136.0 ┆ brown       ┆ … ┆ male ┆ masculine ┆ Kashyyyk  ┆ Wookiee  │
# └───────────────────┴────────┴───────┴─────────────┴───┴──────┴───────────┴───────────┴──────────┘
