# %%
# https://dplyr.tidyverse.org/reference/context.html
# %run nb_helpers.py
from datar.all import *

nb_header(cur_group_id, cur_group_rows, cur_data, cur_data_all, cur_column, book='context')
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Fcontext.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ cur_group_id</div>
# ##### Get the current group id
#
# ##### Args:
# &emsp;&emsp;`_data`: The dataframe
#
# ##### Returns:
# &emsp;&emsp;The current group id
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ cur_group_rows</div>
# ##### Get the current group row indices
#
# ##### Args:
# &emsp;&emsp;`_data`: The dataframe
#
# ##### Returns:
# &emsp;&emsp;The current group rows
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ cur_data</div>
# ##### Get the current dataframe
#
# ##### Args:
# &emsp;&emsp;`_data`: The dataframe
#
# ##### Returns:
# &emsp;&emsp;The current dataframe
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ cur_data_all</div>
# ##### Get the current data for the current group including
# the grouping variables
#
# ##### Args:
# &emsp;&emsp;`_data`: The dataframe
#
# ##### Returns:
# &emsp;&emsp;The current dataframe
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ cur_column</div>
# ##### Get the current column
#
# ##### Args:
# &emsp;&emsp;`_data`: The dataframe
# &emsp;&emsp;`_name`: The column name
#
# ##### Returns:
# &emsp;&emsp;The current column

# %%
df = tibble(
  g=['a'] + ['b'] * 2 + ['c'] * 3,
  x=runif(6),
  y=runif(6)
)
gf = df >> group_by(f.g)

gf >> summarise(n = n())
# Out:
# [2026-05-04 22:10:39][datar][   INFO] `summarise()` has grouped output by ['g'] (override with `_groups` argument)
# shape: (3, 2)
# ┌─────┬─────┐
# │ g   ┆ n   │
# │ --- ┆ --- │
# │ str ┆ u32 │
# ╞═════╪═════╡
# │ a   ┆ 1   │
# │ b   ┆ 2   │
# │ c   ┆ 3   │
# └─────┴─────┘

# %%
gf
# Out:
# shape: (6, 3)
# ┌─────┬──────────┬──────────┐
# │ g   ┆ x        ┆ y        │
# │ --- ┆ ---      ┆ ---      │
# │ str ┆ f64      ┆ f64      │
# ╞═════╪══════════╪══════════╡
# │ a   ┆ 0.495223 ┆ 0.646581 │
# │ b   ┆ 0.56085  ┆ 0.846001 │
# │ b   ┆ 0.092689 ┆ 0.732238 │
# │ c   ┆ 0.532839 ┆ 0.715049 │
# │ c   ┆ 0.782835 ┆ 0.9737   │
# │ c   ┆ 0.813769 ┆ 0.64126  │
# └─────┴──────────┴──────────┘

# %%
gf >> mutate(id=cur_group_id())
# Out:
# shape: (6, 4)
# ┌─────┬──────────┬──────────┬─────┐
# │ g   ┆ x        ┆ y        ┆ id  │
# │ --- ┆ ---      ┆ ---      ┆ --- │
# │ str ┆ f64      ┆ f64      ┆ i32 │
# ╞═════╪══════════╪══════════╪═════╡
# │ a   ┆ 0.495223 ┆ 0.646581 ┆ 0   │
# │ b   ┆ 0.56085  ┆ 0.846001 ┆ 1   │
# │ b   ┆ 0.092689 ┆ 0.732238 ┆ 1   │
# │ c   ┆ 0.532839 ┆ 0.715049 ┆ 2   │
# │ c   ┆ 0.782835 ┆ 0.9737   ┆ 2   │
# │ c   ┆ 0.813769 ┆ 0.64126  ┆ 2   │
# └─────┴──────────┴──────────┴─────┘

# %%
gf >> summarise(row=cur_group_rows())
# Out:
# [2026-05-04 22:10:39][datar][   INFO] `summarise()` has grouped output by ['g'] (override with `_groups` argument)
# shape: (3, 2)
# ┌─────┬───────────┐
# │ g   ┆ row       │
# │ --- ┆ ---       │
# │ str ┆ list[i64] │
# ╞═════╪═══════════╡
# │ a   ┆ [0]       │
# │ b   ┆ [1, 2]    │
# │ c   ┆ [3, 4, 5] │
# └─────┴───────────┘

# %%
gf_group = gf >> summarise(data=cur_group())
gf_group
# Out:
# [2026-05-04 22:10:39][datar][   INFO] `summarise()` has grouped output by ['g'] (override with `_groups` argument)
# shape: (3, 2)
# ┌─────┬───────────┐
# │ g   ┆ data      │
# │ --- ┆ ---       │
# │ str ┆ struct[1] │
# ╞═════╪═══════════╡
# │ a   ┆ {"a"}     │
# │ b   ┆ {"b"}     │
# │ c   ┆ {"c"}     │
# └─────┴───────────┘

# %%
gf_group >> pull(f.data)
# Out:
# shape: (3,)
# Series: 'data' [struct[1]]
# [
# 	{"a"}
# 	{"b"}
# 	{"c"}
# ]

# %%
gf_data = gf >> summarise(data=cur_data())
gf_data
# Out:
# [2026-05-04 22:10:40][datar][   INFO] `summarise()` has grouped output by ['g'] (override with `_groups` argument)
# shape: (3, 2)
# ┌─────┬───────────────────┐
# │ g   ┆ data              │
# │ --- ┆ ---               │
# │ str ┆ object            │
# ╞═════╪═══════════════════╡
# │ a   ┆ shape: (1, 2)     │
# │     ┆ ┌──────────┬────… │
# │ b   ┆ shape: (2, 2)     │
# │     ┆ ┌──────────┬────… │
# │ c   ┆ shape: (3, 2)     │
# │     ┆ ┌──────────┬────… │
# └─────┴───────────────────┘

# %%
gf_data >> pull(f.data, to='list')
# Out:
# [shape: (1, 2)
#  ┌──────────┬──────────┐
#  │ x        ┆ y        │
#  │ ---      ┆ ---      │
#  │ f64      ┆ f64      │
#  ╞══════════╪══════════╡
#  │ 0.495223 ┆ 0.646581 │
#  └──────────┴──────────┘,
#  shape: (2, 2)
#  ┌──────────┬──────────┐
#  │ x        ┆ y        │
#  │ ---      ┆ ---      │
#  │ f64      ┆ f64      │
#  ╞══════════╪══════════╡
#  │ 0.56085  ┆ 0.846001 │
#  │ 0.092689 ┆ 0.732238 │
#  └──────────┴──────────┘,
#  shape: (3, 2)
#  ┌──────────┬──────────┐
#  │ x        ┆ y        │
#  │ ---      ┆ ---      │
#  │ f64      ┆ f64      │
#  ╞══════════╪══════════╡
#  │ 0.532839 ┆ 0.715049 │
#  │ 0.782835 ┆ 0.9737   │
#  │ 0.813769 ┆ 0.64126  │
#  └──────────┴──────────┘]

# %%
gf_data_all = gf >> summarise(data=cur_data_all())
gf_data_all
# Out:
# [2026-05-04 22:10:42][datar][   INFO] `summarise()` has grouped output by ['g'] (override with `_groups` argument)
# shape: (3, 2)
# ┌─────┬───────────────────┐
# │ g   ┆ data              │
# │ --- ┆ ---               │
# │ str ┆ object            │
# ╞═════╪═══════════════════╡
# │ a   ┆ shape: (1, 3)     │
# │     ┆ ┌─────┬─────────… │
# │ b   ┆ shape: (2, 3)     │
# │     ┆ ┌─────┬─────────… │
# │ c   ┆ shape: (3, 3)     │
# │     ┆ ┌─────┬─────────… │
# └─────┴───────────────────┘

# %%
gf_data_all >> pull(f.data, to='list')
# Out:
# [shape: (1, 3)
#  ┌─────┬──────────┬──────────┐
#  │ g   ┆ x        ┆ y        │
#  │ --- ┆ ---      ┆ ---      │
#  │ str ┆ f64      ┆ f64      │
#  ╞═════╪══════════╪══════════╡
#  │ a   ┆ 0.495223 ┆ 0.646581 │
#  └─────┴──────────┴──────────┘,
#  shape: (2, 3)
#  ┌─────┬──────────┬──────────┐
#  │ g   ┆ x        ┆ y        │
#  │ --- ┆ ---      ┆ ---      │
#  │ str ┆ f64      ┆ f64      │
#  ╞═════╪══════════╪══════════╡
#  │ b   ┆ 0.56085  ┆ 0.846001 │
#  │ b   ┆ 0.092689 ┆ 0.732238 │
#  └─────┴──────────┴──────────┘,
#  shape: (3, 3)
#  ┌─────┬──────────┬──────────┐
#  │ g   ┆ x        ┆ y        │
#  │ --- ┆ ---      ┆ ---      │
#  │ str ┆ f64      ┆ f64      │
#  ╞═════╪══════════╪══════════╡
#  │ c   ┆ 0.532839 ┆ 0.715049 │
#  │ c   ┆ 0.782835 ┆ 0.9737   │
#  │ c   ┆ 0.813769 ┆ 0.64126  │
#  └─────┴──────────┴──────────┘]

# %%
# TODO: support this later.
# df >> select(f.x, f.y) >> mutate(
#     across(
#         everything(),
#         lambda x, cc: [cc + ' '] * x.shape[0] + (x**2).astype(str), cc=cur_column()
#     )
# )

# %%
# TODO: support this later.
# # or you can use x.name, since x is a Series
# df >> mutate(across(
#     [f.x, f.y],
#     lambda x: [x.name + ' '] * x.shape[0] + (x**2).astype(str)
# ))
