# %%
# https://dplyr.tidyverse.org/reference/count.html
# %run nb_helpers.py

from datar.data import starwars
from datar.all import *

nb_header(count, tally, add_count, add_tally)
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Fcount.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ count</div>
# ##### Count the number of rows in each group
#
# Original API:
# https://dplyr.tidyverse.org/reference/count.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`*args`: Variables, or functions of variables.
# &emsp;&emsp;&emsp;&emsp;Use desc() to sort a variable in descending order.
#
# &emsp;&emsp;`wt`: A variable or function of variables to weight by.
# &emsp;&emsp;`sort`: If TRUE, the result will be sorted by the count.
# &emsp;&emsp;`name`: The name of the count column.
# &emsp;&emsp;`_drop`: If `False`, keep grouping variables even if they are not used.
# &emsp;&emsp;&emsp;&emsp;Original API does not support this.
#
# &emsp;&emsp;`**kwargs`: Name-value pairs that apply with mutate
#
# ##### Returns:
# &emsp;&emsp;A data frame with the same number of rows as the number of groups.
# &emsp;&emsp;The output has the following properties:
# &emsp;&emsp;&emsp;&emsp;All rows appear in the output, but (usually) in a different place.
# &emsp;&emsp;&emsp;&emsp;Columns are not modified.
# &emsp;&emsp;&emsp;&emsp;Groups are not modified.
# &emsp;&emsp;&emsp;&emsp;Data frame attributes are preserved.
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ tally</div>
# ##### Count the number of rows in each group
#
# Original API:
# https://dplyr.tidyverse.org/reference/count.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`wt`: A variable or function of variables to weight by.
# &emsp;&emsp;`sort`: If TRUE, the result will be sorted by the count.
# &emsp;&emsp;`name`: The name of the count column.
#
# ##### Returns:
# &emsp;&emsp;A data frame with the same number of rows as the number of groups.
# &emsp;&emsp;The output has the following properties:
# &emsp;&emsp;&emsp;&emsp;All rows appear in the output, but (usually) in a different place.
# &emsp;&emsp;&emsp;&emsp;Columns are not modified.
# &emsp;&emsp;&emsp;&emsp;Groups are not modified.
# &emsp;&emsp;&emsp;&emsp;Data frame attributes are preserved.
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ add_count</div>
# ##### Add a count column to a data frame
#
# Original API:
# https://dplyr.tidyverse.org/reference/count.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`*args`: Variables, or functions of variables.
# &emsp;&emsp;&emsp;&emsp;Use desc() to sort a variable in descending order.
#
# &emsp;&emsp;`wt`: A variable or function of variables to weight by.
# &emsp;&emsp;`sort`: If TRUE, the result will be sorted by the count.
# &emsp;&emsp;`name`: The name of the count column.
# &emsp;&emsp;`**kwargs`: Name-value pairs that apply with mutate
#
# ##### Returns:
# &emsp;&emsp;A data frame with the same number of rows as the number of groups.
# &emsp;&emsp;The output has the following properties:
# &emsp;&emsp;&emsp;&emsp;All rows appear in the output, but (usually) in a different place.
# &emsp;&emsp;&emsp;&emsp;Columns are not modified.
# &emsp;&emsp;&emsp;&emsp;Groups are not modified.
# &emsp;&emsp;&emsp;&emsp;Data frame attributes are preserved.
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ add_tally</div>
# ##### Add a count column to a data frame
#
# Original API:
# https://dplyr.tidyverse.org/reference/count.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`wt`: A variable or function of variables to weight by.
# &emsp;&emsp;`sort`: If TRUE, the result will be sorted by the count.
# &emsp;&emsp;`name`: The name of the count column.
#
# ##### Returns:
# &emsp;&emsp;A data frame with the same number of rows as the number of groups.
# &emsp;&emsp;The output has the following properties:
# &emsp;&emsp;&emsp;&emsp;All rows appear in the output, but (usually) in a different place.
# &emsp;&emsp;&emsp;&emsp;Columns are not modified.
# &emsp;&emsp;&emsp;&emsp;Groups are not modified.
# &emsp;&emsp;&emsp;&emsp;Data frame attributes are preserved.

# %%
starwars >> count(f.species)
# Out:
# [2026-05-04 23:14:46][datar][   INFO] `summarise()` has grouped output by ['species'] (override with `_groups` argument)
# shape: (38, 2)
# ┌─────────┬─────┐
# │ species ┆ n   │
# │ ---     ┆ --- │
# │ str     ┆ i64 │
# ╞═════════╪═════╡
# │ Human   ┆ 35  │
# │ Droid   ┆ 6   │
# │ Wookiee ┆ 2   │
# │ Rodian  ┆ 1   │
# │ Hutt    ┆ 1   │
# │ …       ┆ …   │
# │ Skakoan ┆ 1   │
# │ Muun    ┆ 1   │
# │ Togruta ┆ 1   │
# │ Kaleesh ┆ 1   │
# │ Pau'an  ┆ 1   │
# └─────────┴─────┘

# %%
starwars >> count(f.species, sort=True)
# Out:
# [2026-05-04 23:14:46][datar][   INFO] `summarise()` has grouped output by ['species'] (override with `_groups` argument)
# shape: (38, 2)
# ┌─────────┬─────┐
# │ species ┆ n   │
# │ ---     ┆ --- │
# │ str     ┆ i64 │
# ╞═════════╪═════╡
# │ Human   ┆ 35  │
# │ Droid   ┆ 6   │
# │ null    ┆ 4   │
# │ Gungan  ┆ 3   │
# │ Wookiee ┆ 2   │
# │ …       ┆ …   │
# │ Skakoan ┆ 1   │
# │ Muun    ┆ 1   │
# │ Togruta ┆ 1   │
# │ Kaleesh ┆ 1   │
# │ Pau'an  ┆ 1   │
# └─────────┴─────┘

# %%
starwars >> count(f.sex, f.gender, sort=True)
# Out:
# [2026-05-04 23:14:46][datar][   INFO] `summarise()` has grouped output by ['sex'] (override with `_groups` argument)
# shape: (6, 3)
# ┌────────────────┬───────────┬─────┐
# │ sex            ┆ gender    ┆ n   │
# │ ---            ┆ ---       ┆ --- │
# │ str            ┆ str       ┆ i64 │
# ╞════════════════╪═══════════╪═════╡
# │ male           ┆ masculine ┆ 60  │
# │ female         ┆ feminine  ┆ 16  │
# │ none           ┆ masculine ┆ 5   │
# │ null           ┆ null      ┆ 4   │
# │ hermaphroditic ┆ masculine ┆ 1   │
# │ none           ┆ feminine  ┆ 1   │
# └────────────────┴───────────┴─────┘

# %%
starwars >> count(birth_decade=round_(f.birth_year, -1))
# Out:
# [2026-05-04 23:14:48][datar][   INFO] `summarise()` has grouped output by ['birth_decade'] (override with `_groups` argument)
# shape: (15, 2)
# ┌──────────────┬─────┐
# │ birth_decade ┆ n   │
# │ ---          ┆ --- │
# │ f64          ┆ i64 │
# ╞══════════════╪═════╡
# │ 20.0         ┆ 6   │
# │ 110.0        ┆ 1   │
# │ 30.0         ┆ 4   │
# │ 40.0         ┆ 6   │
# │ 50.0         ┆ 8   │
# │ …            ┆ …   │
# │ 80.0         ┆ 2   │
# │ 10.0         ┆ 1   │
# │ 90.0         ┆ 3   │
# │ 70.0         ┆ 4   │
# │ 100.0        ┆ 1   │
# └──────────────┴─────┘

# %%
df = tribble(
  f.name,    f.gender,   f.runs,
  "Max",    "male",       10,
  "Sandra", "female",      1,
  "Susan",  "female",      4
)
# counts rows:
df >> count(f.gender)
# Out:
# [2026-05-04 23:15:09][datar][   INFO] `summarise()` has grouped output by ['gender'] (override with `_groups` argument)
# shape: (2, 2)
# ┌────────┬─────┐
# │ gender ┆ n   │
# │ ---    ┆ --- │
# │ str    ┆ i64 │
# ╞════════╪═════╡
# │ male   ┆ 1   │
# │ female ┆ 2   │
# └────────┴─────┘

# %%
df >> count(f.gender, wt=f.runs)
# Out:
# [2026-05-04 23:15:12][datar][   INFO] `summarise()` has grouped output by ['gender'] (override with `_groups` argument)
# shape: (2, 2)
# ┌────────┬─────┐
# │ gender ┆ n   │
# │ ---    ┆ --- │
# │ str    ┆ i64 │
# ╞════════╪═════╡
# │ male   ┆ 10  │
# │ female ┆ 5   │
# └────────┴─────┘

# %%
starwars >> tally()
# Out:
# shape: (1, 1)
# ┌─────┐
# │ n   │
# │ --- │
# │ i64 │
# ╞═════╡
# │ 87  │
# └─────┘

# %%
starwars >> group_by(f.species) >> tally()
# Out:
# [2026-05-04 23:15:18][datar][   INFO] `summarise()` has grouped output by ['species'] (override with `_groups` argument)
# shape: (38, 2)
# ┌─────────┬─────┐
# │ species ┆ n   │
# │ ---     ┆ --- │
# │ str     ┆ i64 │
# ╞═════════╪═════╡
# │ Human   ┆ 35  │
# │ Droid   ┆ 6   │
# │ Wookiee ┆ 2   │
# │ Rodian  ┆ 1   │
# │ Hutt    ┆ 1   │
# │ …       ┆ …   │
# │ Skakoan ┆ 1   │
# │ Muun    ┆ 1   │
# │ Togruta ┆ 1   │
# │ Kaleesh ┆ 1   │
# │ Pau'an  ┆ 1   │
# └─────────┴─────┘

# %%
df >> add_count(f.gender, wt=f.runs)
# Out:
# shape: (3, 4)
# ┌────────┬────────┬──────┬─────┐
# │ name   ┆ gender ┆ runs ┆ n   │
# │ ---    ┆ ---    ┆ ---  ┆ --- │
# │ str    ┆ str    ┆ i64  ┆ i64 │
# ╞════════╪════════╪══════╪═════╡
# │ Max    ┆ male   ┆ 10   ┆ 10  │
# │ Sandra ┆ female ┆ 1    ┆ 5   │
# │ Susan  ┆ female ┆ 4    ┆ 5   │
# └────────┴────────┴──────┴─────┘

# %%
df >> add_tally(wt=f.runs)
# Out:
# shape: (3, 4)
# ┌────────┬────────┬──────┬─────┐
# │ name   ┆ gender ┆ runs ┆ n   │
# │ ---    ┆ ---    ┆ ---  ┆ --- │
# │ str    ┆ str    ┆ i64  ┆ i64 │
# ╞════════╪════════╪══════╪═════╡
# │ Max    ┆ male   ┆ 10   ┆ 15  │
# │ Sandra ┆ female ┆ 1    ┆ 15  │
# │ Susan  ┆ female ┆ 4    ┆ 15  │
# └────────┴────────┴──────┴─────┘
