# %%
# https://dplyr.tidyverse.org/reference/rowwise.html
# %run nb_helpers.py

from datar.all import *

nb_header(rowwise)
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Frowwise.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ rowwise</div>
# ##### Create a rowwise frame
#
# The original API:
# https://dplyr.tidyverse.org/reference/rowwise.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`*cols`: Columns to make rowwise.
#
# ##### Returns:
# &emsp;&emsp;A rowwise frame

# %%
df = tibble(x=runif(6), y=runif(6), z=runif(6))

df >> rowwise() >> mutate(m=mean(c_across(c(f.x, f.y, f.z))))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedByCurrentBackendError       Traceback (most recent call last)
# Cell In[2], line 3
#       1 df = tibble(x=runif(6), y=runif(6), z=runif(6))
#       2
# ----> 3 df >> rowwise() >> mutate(m=mean(c_across(c(f.x, f.y, f.z))))
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/pipda/verb.py:73, in VerbCall._pipda_eval(self, data, context)
#      71     context = context.value
#      72 if isinstance(context, ContextPending):
# ---> 73     return func(data, *self._pipda_args, **self._pipda_kwargs)
#      75 args = (evaluate_expr(arg, data, context) for arg in self._pipda_args)
#      76 kwargs = {
#      77     key: evaluate_expr(val, data, kw_context.get(key, context))
#      78     for key, val in self._pipda_kwargs.items()
#      79 }
#
# File ~/workspace/datar-polars/datar_polars/api/dplyr/mutate.py:317, in _mutate_eager(_data, _keep, _before, _after, *args, **kwargs)
#     307 @mutate.register(pl.DataFrame, context=Context.PENDING, backend="polars")
#     308 def _mutate_eager(
#     309     _data: pl.DataFrame,
#    (...)    314     **kwargs: Any,
#     315 ) -> Tibble:
#     316     return to_eager(
# --> 317         _mutate_impl(
#     318             to_lazy(_data),
#     319             *args,
#     320             _keep=_keep,
#     321             _before=_before,
#     322             _after=_after,
#     323             **kwargs,
#     324         )
#     325     )
#
# File ~/workspace/datar-polars/datar_polars/api/dplyr/mutate.py:125, in _mutate_impl(_data, _keep, _before, _after, *args, **kwargs)
#     123 # Evaluate keyword args
#     124 for key, val_expr in kwargs.items():
# --> 125     evaluated = evaluate_expr(val_expr, row_dict, cast(Any, Context.EVAL))
#     126     row_dict[key] = evaluated
#     128 result_rows.append(row_dict)
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/pipda/utils.py:133, in evaluate_expr(expr, data, context)
#     128     context = context.value
#     130 if hasattr(expr.__class__, "_pipda_eval"):
#     131     # Not only for Expression objects, but also
#     132     # allow customized classes
# --> 133     return expr._pipda_eval(data, context)
#     135 if isinstance(expr, (tuple, list, set)):
#     136     # In case it's subclass
#     137     return expr.__class__(
#     138         (evaluate_expr(elem, data, context) for elem in expr)
#     139     )
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/pipda/function.py:92, in FunctionCall._pipda_eval(self, data, context)
#      87     kwargs = {
#      88         key: evaluate_expr(val, dt, kw_ctx.get(key, ctx))
#      89         for key, val in kwargs.items()
#      90     }
#      91 else:
# ---> 92     args = tuple(
#      93         evaluate_expr(arg, data, context)
#      94         for arg in args
#      95     )
#      96     kwargs = {
#      97         key: evaluate_expr(val, data, context)
#      98         for key, val in kwargs.items()
#      99     }
#     100     if functype == "func":
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/pipda/function.py:93, in <genexpr>(.0)
#      87     kwargs = {
#      88         key: evaluate_expr(val, dt, kw_ctx.get(key, ctx))
#      89         for key, val in kwargs.items()
#      90     }
#      91 else:
#      92     args = tuple(
# ---> 93         evaluate_expr(arg, data, context)
#      94         for arg in args
#      95     )
#      96     kwargs = {
#      97         key: evaluate_expr(val, data, context)
#      98         for key, val in kwargs.items()
#      99     }
#     100     if functype == "func":
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/pipda/utils.py:133, in evaluate_expr(expr, data, context)
#     128     context = context.value
#     130 if hasattr(expr.__class__, "_pipda_eval"):
#     131     # Not only for Expression objects, but also
#     132     # allow customized classes
# --> 133     return expr._pipda_eval(data, context)
#     135 if isinstance(expr, (tuple, list, set)):
#     136     # In case it's subclass
#     137     return expr.__class__(
#     138         (evaluate_expr(elem, data, context) for elem in expr)
#     139     )
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/pipda/verb.py:80, in VerbCall._pipda_eval(self, data, context)
#      75 args = (evaluate_expr(arg, data, context) for arg in self._pipda_args)
#      76 kwargs = {
#      77     key: evaluate_expr(val, data, kw_context.get(key, context))
#      78     for key, val in self._pipda_kwargs.items()
#      79 }
# ---> 80 return func(data, *args, **kwargs)
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/datar/apis/dplyr.py:102, in c_across(_data, _cols)
#      91 @_register_verb(dependent=True, ast_fallback=_get_verb_ast_fallback("c_across"))
#      92 def c_across(_data: T, _cols=None) -> T:
#      93     """Apply the same transformation to multiple columns rowwisely
#      94
#      95     Args:
#    (...)    100         A rowwise tibble
#     101     """
# --> 102     raise _NotImplementedByCurrentBackendError("c_across", _data)
#
# NotImplementedByCurrentBackendError: 'c_across' (data type: dict, backends: polars)

# %%
df >> rowwise() >> mutate(m=mean(c_across(f[f.x:])))
# Out:
# shape: (6, 4)
# ┌──────────┬──────────┬──────────┬──────────┐
# │ x        ┆ y        ┆ z        ┆ m        │
# │ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════╪══════════╪══════════╪══════════╡
# │ 0.635259 ┆ 0.786415 ┆ 0.103071 ┆ 0.508248 │
# │ 0.10596  ┆ 0.012209 ┆ 0.257348 ┆ 0.125172 │
# │ 0.407749 ┆ 0.95611  ┆ 0.000144 ┆ 0.454668 │
# │ 0.347562 ┆ 0.902082 ┆ 0.551112 ┆ 0.600252 │
# │ 0.76216  ┆ 0.722251 ┆ 0.123598 ┆ 0.536003 │
# │ 0.249405 ┆ 0.405172 ┆ 0.512022 ┆ 0.388866 │
# └──────────┴──────────┴──────────┴──────────┘

# %%
df >> rowwise() >> mutate(m=min(c_across([f.x, f.y, f.z])))
# Out:
# shape: (6, 4)
# ┌──────────┬──────────┬──────────┬──────────┐
# │ x        ┆ y        ┆ z        ┆ m        │
# │ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════╪══════════╪══════════╪══════════╡
# │ 0.635259 ┆ 0.786415 ┆ 0.103071 ┆ 0.103071 │
# │ 0.10596  ┆ 0.012209 ┆ 0.257348 ┆ 0.012209 │
# │ 0.407749 ┆ 0.95611  ┆ 0.000144 ┆ 0.000144 │
# │ 0.347562 ┆ 0.902082 ┆ 0.551112 ┆ 0.347562 │
# │ 0.76216  ┆ 0.722251 ┆ 0.123598 ┆ 0.123598 │
# │ 0.249405 ┆ 0.405172 ┆ 0.512022 ┆ 0.249405 │
# └──────────┴──────────┴──────────┴──────────┘

# %%
df >> rowwise() >> mutate(m=min(c_across(f[f.x:])))
# Out:
# shape: (6, 4)
# ┌──────────┬──────────┬──────────┬──────────┐
# │ x        ┆ y        ┆ z        ┆ m        │
# │ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════╪══════════╪══════════╪══════════╡
# │ 0.635259 ┆ 0.786415 ┆ 0.103071 ┆ 0.103071 │
# │ 0.10596  ┆ 0.012209 ┆ 0.257348 ┆ 0.012209 │
# │ 0.407749 ┆ 0.95611  ┆ 0.000144 ┆ 0.000144 │
# │ 0.347562 ┆ 0.902082 ┆ 0.551112 ┆ 0.347562 │
# │ 0.76216  ┆ 0.722251 ┆ 0.123598 ┆ 0.123598 │
# │ 0.249405 ┆ 0.405172 ┆ 0.512022 ┆ 0.249405 │
# └──────────┴──────────┴──────────┴──────────┘

# %%
df >> mutate(m = pmin(f.x, f.y, f.z))
# Out:
# shape: (6, 4)
# ┌──────────┬──────────┬──────────┬──────────┐
# │ x        ┆ y        ┆ z        ┆ m        │
# │ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════╪══════════╪══════════╪══════════╡
# │ 0.462009 ┆ 0.03004  ┆ 0.660159 ┆ 0.03004  │
# │ 0.951516 ┆ 0.402051 ┆ 0.596688 ┆ 0.402051 │
# │ 0.055899 ┆ 0.633902 ┆ 0.266161 ┆ 0.055899 │
# │ 0.096506 ┆ 0.093556 ┆ 0.780327 ┆ 0.093556 │
# │ 0.225075 ┆ 0.236667 ┆ 0.390709 ┆ 0.225075 │
# │ 0.599524 ┆ 0.080819 ┆ 0.492144 ┆ 0.080819 │
# └──────────┴──────────┴──────────┴──────────┘

# %%
params = tibble(
    sim=[1, 2, 3],
    n=[1, 2, 3],
    mean=[1, 2, 1],
    sd=[1, 4, 2]
)

params >> rowwise(f.sim) >> mutate(z=rnorm(f.n, f.mean, f.sd))
# Out:
# shape: (3, 5)
# ┌─────┬─────┬──────┬─────┬─────────────────────────────────┐
# │ sim ┆ n   ┆ mean ┆ sd  ┆ z                               │
# │ --- ┆ --- ┆ ---  ┆ --- ┆ ---                             │
# │ i64 ┆ i64 ┆ i64  ┆ i64 ┆ list[f64]                       │
# ╞═════╪═════╪══════╪═════╪═════════════════════════════════╡
# │ 1   ┆ 1   ┆ 1    ┆ 1   ┆ [1.948341]                      │
# │ 2   ┆ 2   ┆ 2    ┆ 4   ┆ [-2.766173, 5.972079]           │
# │ 3   ┆ 3   ┆ 1    ┆ 2   ┆ [-1.933921, 2.076103, 0.502007… │
# └─────┴─────┴──────┴─────┴─────────────────────────────────┘
