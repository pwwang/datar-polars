# %%
# https://dplyr.tidyverse.org/reference/distinct.html
# %run nb_helpers.py
from datar.data import starwars
from datar.all import *

nb_header(distinct, n_distinct, book='distinct')
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Fdistinct.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ distinct</div>
# ##### Filter a data frame based on conditions
#
# The original API:
# https://dplyr.tidyverse.org/reference/distinct.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`*args`: Variables to filter by.
# &emsp;&emsp;`keep_all`: If `True`, keep all rows that match.
# &emsp;&emsp;`_preserve`: If `True`, keep grouping variables even if they are not used.
#
# ##### Returns:
# &emsp;&emsp;The subset dataframe
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ n_distinct</div>
# ##### Count the number of distinct values
#
# The original API:
# https://dplyr.tidyverse.org/reference/distinct.html
#
# ##### Args:
# &emsp;&emsp;`_data`: A data frame
# &emsp;&emsp;`na_rm`: If `True`, remove missing values before counting.
#
# ##### Returns:
# &emsp;&emsp;The number of distinct values

# %%
df = tibble(
  x=sample(range(10), 100, replace=True),
  y=sample(range(10), 100, replace=True)
)
nrow(df)
# Out:
# 100

# %%
nrow(distinct(df))
# Out:
# 60

# %%
df >> distinct(f.x, f.y) >> nrow()
# Out:
# 60

# %%
df >> distinct(f.x)
# Out:
# shape: (10, 1)
# ┌─────┐
# │ x   │
# │ --- │
# │ i64 │
# ╞═════╡
# │ 0   │
# │ 9   │
# │ 3   │
# │ 4   │
# │ 8   │
# │ 2   │
# │ 7   │
# │ 1   │
# │ 6   │
# │ 5   │
# └─────┘

# %%
df >> distinct(f.y)
# Out:
# shape: (10, 1)
# ┌─────┐
# │ y   │
# │ --- │
# │ i64 │
# ╞═════╡
# │ 5   │
# │ 6   │
# │ 3   │
# │ 7   │
# │ 8   │
# │ 1   │
# │ 9   │
# │ 0   │
# │ 4   │
# │ 2   │
# └─────┘

# %%
df >> distinct(f.x, _keep_all=True)
# Out:
# shape: (10, 2)
# ┌─────┬─────┐
# │ x   ┆ y   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 0   ┆ 5   │
# │ 9   ┆ 6   │
# │ 3   ┆ 3   │
# │ 4   ┆ 8   │
# │ 8   ┆ 3   │
# │ 2   ┆ 8   │
# │ 7   ┆ 7   │
# │ 1   ┆ 1   │
# │ 6   ┆ 3   │
# │ 5   ┆ 0   │
# └─────┴─────┘

# %%
df >> distinct(f.y, _keep_all=True)
# Out:
# shape: (10, 2)
# ┌─────┬─────┐
# │ x   ┆ y   │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 0   ┆ 5   │
# │ 9   ┆ 6   │
# │ 3   ┆ 3   │
# │ 3   ┆ 7   │
# │ 4   ┆ 8   │
# │ 3   ┆ 1   │
# │ 9   ┆ 9   │
# │ 5   ┆ 0   │
# │ 6   ┆ 4   │
# │ 1   ┆ 2   │
# └─────┴─────┘

# %%
df >> distinct(diff=abs(f.x-f.y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df >> distinct(diff=abs(f.x-f.y))
#
# File ~/workspace/datar-polars/.venv/lib/python3.13/site-packages/pipda/verb.py:73, in VerbCall._pipda_eval(self, data, context)
#      71     context = context.value
#      72 if isinstance(context, ContextPending):
# ---> 73     return func(data, *self._pipda_args, **self._pipda_kwargs)
#      75 args = (evaluate_expr(arg, data, context) for arg in self._pipda_args)
#      76 kwargs = {
#      77     key: evaluate_expr(val, data, kw_context.get(key, context))
#      78     for key, val in self._pipda_kwargs.items()
#      79 }
#
# File ~/workspace/datar-polars/datar_polars/api/dplyr/distinct.py:86, in _distinct(_data, _keep_all, *args, **kwargs)
#      83     selected_cols = []
#      85 if kwargs:
# ---> 86     kw_idx = vars_select(all_cols, *kwargs.values())
#      87     kw_cols = [all_cols[i] for i in kw_idx]
#      88 else:
#
# File ~/workspace/datar-polars/datar_polars/utils.py:123, in vars_select(all_columns, raise_nonexists, *columns)
#     119     raise KeyError(f"Columns `{selected.unmatched}` do not exist.")
#     121 from .common import unique
# --> 123 return unique(selected).astype(int)
#
# File ~/workspace/datar-polars/datar_polars/common.py:21, in unique(x)
#      19         seen.add(item)
#      20         result.append(item)
# ---> 21 return np.array(result)
#
# ValueError: invalid __array_struct__

# %%
starwars >> distinct(across(contains("color")))
# Out:
#    hair_color   skin_color eye_color
#      <object>     <object>  <object>
# 0       blond         fair      blue
# 1         NaN         gold    yellow
# 2         NaN  white, blue       red
# 3        none        white    yellow
# ..        ...          ...       ...
# 4       brown        light     brown
# 79       none         pale     white
# 81      black         dark      dark
# 82      brown        light     hazel
# 84       none         none     black
# 85    unknown      unknown   unknown
#
# [67 rows x 3 columns]

# %%
df = tibble(
  g=[1, 1, 2, 2],
  x=[1, 1, 2, 1]
) >> group_by(f.g)

df >> distinct(f.x)
# Out:
#         g       x
#   <int64> <int64>
# 0       1       1
# 2       2       2
# [TibbleGrouped: g (n=2)]
