# %%
# %run nb_helpers.py

from datar.data import mtcars
from datar.all import *
from datar_polars import lazy, collect

# %%
mtcars >> lazy()
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>DF ["", "mpg", "cyl", "disp", ...]; PROJECT */12 COLUMNS</div>

# %%
mtcars >> lazy() >> collect()
# Out:
# shape: (32, 12)
# ┌───────────────────┬──────┬─────┬───────┬───┬─────┬─────┬──────┬──────┐
# │                   ┆ mpg  ┆ cyl ┆ disp  ┆ … ┆ vs  ┆ am  ┆ gear ┆ carb │
# │ ---               ┆ ---  ┆ --- ┆ ---   ┆   ┆ --- ┆ --- ┆ ---  ┆ ---  │
# │ str               ┆ f64  ┆ i64 ┆ f64   ┆   ┆ i64 ┆ i64 ┆ i64  ┆ i64  │
# ╞═══════════════════╪══════╪═════╪═══════╪═══╪═════╪═════╪══════╪══════╡
# │ Mazda RX4         ┆ 21.0 ┆ 6   ┆ 160.0 ┆ … ┆ 0   ┆ 1   ┆ 4    ┆ 4    │
# │ Mazda RX4 Wag     ┆ 21.0 ┆ 6   ┆ 160.0 ┆ … ┆ 0   ┆ 1   ┆ 4    ┆ 4    │
# │ Datsun 710        ┆ 22.8 ┆ 4   ┆ 108.0 ┆ … ┆ 1   ┆ 1   ┆ 4    ┆ 1    │
# │ Hornet 4 Drive    ┆ 21.4 ┆ 6   ┆ 258.0 ┆ … ┆ 1   ┆ 0   ┆ 3    ┆ 1    │
# │ Hornet Sportabout ┆ 18.7 ┆ 8   ┆ 360.0 ┆ … ┆ 0   ┆ 0   ┆ 3    ┆ 2    │
# │ …                 ┆ …    ┆ …   ┆ …     ┆ … ┆ …   ┆ …   ┆ …    ┆ …    │
# │ Lotus Europa      ┆ 30.4 ┆ 4   ┆ 95.1  ┆ … ┆ 1   ┆ 1   ┆ 5    ┆ 2    │
# │ Ford Pantera L    ┆ 15.8 ┆ 8   ┆ 351.0 ┆ … ┆ 0   ┆ 1   ┆ 5    ┆ 4    │
# ...

# %%
(
    mtcars
    >> lazy()
    >> group_by(f.cyl)
    >> mutate(mpg = f.mpg * 2)
    >> summarise(mean = f.mpg.mean())
)
# Out:
# [2026-05-05 08:24:10][datar][   INFO] `summarise()` has grouped output by ['cyl'] (override with `_groups` argument)
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div>AGGREGATE[maintain_order: true]<p></p>  [col("mpg").mean().alias("mean")] BY [col("cyl")]<p></p>  FROM<p></p>  SELECT [col(""), col("mpg"), col("cyl"), col("disp"), col("hp"), col("drat"), col("wt"), col("qsec"), col("vs"), col("am"), col("gear"), col("carb")]<p></p>     WITH_COLUMNS:<p></p>     [[(col("mpg")) * (2.0)]] <p></p>      DF ["", "mpg", "cyl", "disp", ...]; PROJECT */12 COLUMNS</div>

# %%
(
    mtcars
    >> lazy()
    >> group_by(f.cyl)
    >> mutate(mpg = f.mpg * 2)
    >> summarise(mean = f.mpg.mean())
    >> collect()
)
# Out:
# [2026-05-05 08:23:59][datar][   INFO] `summarise()` has grouped output by ['cyl'] (override with `_groups` argument)
# shape: (3, 2)
# ┌─────┬───────────┐
# │ cyl ┆ mean      │
# │ --- ┆ ---       │
# │ i64 ┆ f64       │
# ╞═════╪═══════════╡
# │ 6   ┆ 39.485714 │
# │ 4   ┆ 53.327273 │
# │ 8   ┆ 30.2      │
# └─────┴───────────┘
