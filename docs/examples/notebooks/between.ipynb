# %%
# https://dplyr.tidyverse.org/reference/between.html
# %run nb_helpers.py

from datar.data import starwars
from datar.all import *

nb_header(between)
# Out:
# <div style="text-align: right; text-style: italic">Try this notebook on <a target="_blank" href="https://mybinder.org/v2/gh/pwwang/datar/dev?filepath=docs%2Fnotebooks%2Fbetween.ipynb">binder</a>.</div>
# ### <div style="background-color: #EEE; padding: 5px 0 8px 0">★ between</div>
# ##### Check if a value is between two other values
#
# The original API:
# https://dplyr.tidyverse.org/reference/between.html
#
# ##### Args:
# &emsp;&emsp;`x`: A value
# &emsp;&emsp;`left`: The left bound
# &emsp;&emsp;`right`: The right bound
# &emsp;&emsp;`inclusive`: Either `both`, `neither`, `left` or `right`.
# &emsp;&emsp;&emsp;&emsp;Include boundaries. Whether to set each bound as closed or open.
#
# ##### Returns:
# &emsp;&emsp;A bool value if `x` is scalar, otherwise an array of boolean values
# &emsp;&emsp;Note that it will be always False when NA appears in x, left or right.

# %%
between(range(1, 13), 7, 9)
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False]

# %%
x = rnorm(100)
x[between(x, -1, 1)]
# Out:
# shape: (70,)
# Series: '' [f64]
# [
# 	-0.042495
# 	-0.152627
# 	0.807189
# 	-0.56932
# 	-0.120073
# 	…
# 	-0.752433
# 	-0.834877
# 	-0.044108
# 	0.554008
# 	-0.399589
# ]

# %%
starwars
# Out:
# shape: (87, 11)
# ┌────────────────┬────────┬───────┬────────────┬───┬────────┬───────────┬───────────┬─────────┐
# │ name           ┆ height ┆ mass  ┆ hair_color ┆ … ┆ sex    ┆ gender    ┆ homeworld ┆ species │
# │ ---            ┆ ---    ┆ ---   ┆ ---        ┆   ┆ ---    ┆ ---       ┆ ---       ┆ ---     │
# │ str            ┆ i64    ┆ f64   ┆ str        ┆   ┆ str    ┆ str       ┆ str       ┆ str     │
# ╞════════════════╪════════╪═══════╪════════════╪═══╪════════╪═══════════╪═══════════╪═════════╡
# │ Luke Skywalker ┆ 172    ┆ 77.0  ┆ blond      ┆ … ┆ male   ┆ masculine ┆ Tatooine  ┆ Human   │
# │ C-3PO          ┆ 167    ┆ 75.0  ┆ null       ┆ … ┆ none   ┆ masculine ┆ Tatooine  ┆ Droid   │
# │ R2-D2          ┆ 96     ┆ 32.0  ┆ null       ┆ … ┆ none   ┆ masculine ┆ Naboo     ┆ Droid   │
# │ Darth Vader    ┆ 202    ┆ 136.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Tatooine  ┆ Human   │
# │ Leia Organa    ┆ 150    ┆ 49.0  ┆ brown      ┆ … ┆ female ┆ feminine  ┆ Alderaan  ┆ Human   │
# │ …              ┆ …      ┆ …     ┆ …          ┆ … ┆ …      ┆ …         ┆ …         ┆ …       │
# │ Rey            ┆ null   ┆ null  ┆ brown      ┆ … ┆ female ┆ feminine  ┆ null      ┆ Human   │
# │ Poe Dameron    ┆ null   ┆ null  ┆ brown      ┆ … ┆ male   ┆ masculine ┆ null      ┆ Human   │
# │ BB8            ┆ null   ┆ null  ┆ none       ┆ … ┆ none   ┆ masculine ┆ null      ┆ Droid   │
# │ Captain Phasma ┆ null   ┆ null  ┆ unknown    ┆ … ┆ null   ┆ null      ┆ null      ┆ null    │
# │ Padmé Amidala  ┆ 165    ┆ 45.0  ┆ brown      ┆ … ┆ female ┆ feminine  ┆ Naboo     ┆ Human   │
# └────────────────┴────────┴───────┴────────────┴───┴────────┴───────────┴───────────┴─────────┘

# %%
starwars >> filter_(between(f.height, 100, 150))
# Out:
# shape: (5, 11)
# ┌─────────────┬────────┬──────┬────────────┬───┬────────┬───────────┬───────────┬───────────┐
# │ name        ┆ height ┆ mass ┆ hair_color ┆ … ┆ sex    ┆ gender    ┆ homeworld ┆ species   │
# │ ---         ┆ ---    ┆ ---  ┆ ---        ┆   ┆ ---    ┆ ---       ┆ ---       ┆ ---       │
# │ str         ┆ i64    ┆ f64  ┆ str        ┆   ┆ str    ┆ str       ┆ str       ┆ str       │
# ╞═════════════╪════════╪══════╪════════════╪═══╪════════╪═══════════╪═══════════╪═══════════╡
# │ Leia Organa ┆ 150    ┆ 49.0 ┆ brown      ┆ … ┆ female ┆ feminine  ┆ Alderaan  ┆ Human     │
# │ Mon Mothma  ┆ 150    ┆ null ┆ auburn     ┆ … ┆ female ┆ feminine  ┆ Chandrila ┆ Human     │
# │ Watto       ┆ 137    ┆ null ┆ black      ┆ … ┆ male   ┆ masculine ┆ Toydaria  ┆ Toydarian │
# │ Sebulba     ┆ 112    ┆ 40.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Malastare ┆ Dug       │
# │ Gasgano     ┆ 122    ┆ null ┆ none       ┆ … ┆ male   ┆ masculine ┆ Troiken   ┆ Xexto     │
# └─────────────┴────────┴──────┴────────────┴───┴────────┴───────────┴───────────┴───────────┘

# %%
starwars >> filter(100 <= f.height <= 150) # not as expected
# Out:
# shape: (12, 11)
# ┌───────────────┬────────┬──────┬────────────┬───┬────────┬───────────┬─────────────┬──────────────┐
# │ name          ┆ height ┆ mass ┆ hair_color ┆ … ┆ sex    ┆ gender    ┆ homeworld   ┆ species      │
# │ ---           ┆ ---    ┆ ---  ┆ ---        ┆   ┆ ---    ┆ ---       ┆ ---         ┆ ---          │
# │ str           ┆ i64    ┆ f64  ┆ str        ┆   ┆ str    ┆ str       ┆ str         ┆ str          │
# ╞═══════════════╪════════╪══════╪════════════╪═══╪════════╪═══════════╪═════════════╪══════════════╡
# │ R2-D2         ┆ 96     ┆ 32.0 ┆ null       ┆ … ┆ none   ┆ masculine ┆ Naboo       ┆ Droid        │
# │ Leia Organa   ┆ 150    ┆ 49.0 ┆ brown      ┆ … ┆ female ┆ feminine  ┆ Alderaan    ┆ Human        │
# │ R5-D4         ┆ 97     ┆ 32.0 ┆ null       ┆ … ┆ none   ┆ masculine ┆ Tatooine    ┆ Droid        │
# │ Yoda          ┆ 66     ┆ 17.0 ┆ white      ┆ … ┆ male   ┆ masculine ┆ null        ┆ Yoda's       │
# │               ┆        ┆      ┆            ┆   ┆        ┆           ┆             ┆ species      │
# │ Mon Mothma    ┆ 150    ┆ null ┆ auburn     ┆ … ┆ female ┆ feminine  ┆ Chandrila   ┆ Human        │
# │ …             ┆ …      ┆ …    ┆ …          ┆ … ┆ …      ┆ …         ┆ …           ┆ …            │
# │ Sebulba       ┆ 112    ┆ 40.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Malastare   ┆ Dug          │
# │ Dud Bolt      ┆ 94     ┆ 45.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Vulpter     ┆ Vulptereen   │
# │ Gasgano       ┆ 122    ┆ null ┆ none       ┆ … ┆ male   ┆ masculine ┆ Troiken     ┆ Xexto        │
# │ Ratts Tyerell ┆ 79     ┆ 15.0 ┆ none       ┆ … ┆ male   ┆ masculine ┆ Aleen Minor ┆ Aleena       │
# │ R4-P17        ┆ 96     ┆ null ┆ none       ┆ … ┆ none   ┆ feminine  ┆ null        ┆ Droid        │
# └───────────────┴────────┴──────┴────────────┴───┴────────┴───────────┴─────────────┴──────────────┘
